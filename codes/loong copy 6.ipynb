# %% [markdown]
# # getting data from the one minute dataset

# %% [markdown]
# # rollong mean of the volume

# %% [markdown]
# # select which stock to be used in the analysis

# %% [markdown]
# Top Trading Volume Stocks & AAPL & MGM & FITB & MPC & GS \\
# Bottom Trading Volume Stocks & AEP & HP & KLAC & GPN & ROK \\

# %%
lst = ['AAPL', 'MGM','FITB','MPC','GS','AEP','HP','KLAC','GPN','ROK']
for symbol in lst:

# %%
# %%bash
# cd /scratch/local/kang/
# ls -lh
# Out:
# total 80G
# drwxr-sr-x  4 kang flair-users   48 Nov 26 14:36 AMZN_data
# drwxr-sr-x  2 kang flair-users 4.0K Aug 16  2023 cmem
# drwxr-sr-x  4 kang flair-users   48 Nov 26 14:36 _data
# -r-x------  1 kang flair-users 220M Nov 26 14:24 _data_dwn_32_302__A_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 684M Nov 26 14:24 _data_dwn_32_302__AAL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 175M Nov 26 14:24 _data_dwn_32_302__AAP_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 2.3G Nov 26 14:24 _data_dwn_32_302__AAPL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 457M Nov 26 14:25 _data_dwn_32_302__ABBV_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 194M Nov 26 14:25 _data_dwn_32_302__ABC_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users  92M Nov 26 14:25 _data_dwn_32_302__ABMD_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 411M Nov 26 14:25 _data_dwn_32_302__ABT_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 232M Nov 26 14:25 _data_dwn_32_302__ACN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 430M Nov 26 14:25 _data_dwn_32_302__ADBE_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 434M Nov 26 14:25 _data_dwn_32_302__ADI_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 300M Nov 26 14:25 _data_dwn_32_302__ADM_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 375M Nov 26 14:25 _data_dwn_32_302__ADP_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 109M Nov 26 14:25 _data_dwn_32_302__ADS_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 381M Nov 26 14:25 _data_dwn_32_302__ADSK_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 176M Nov 26 14:25 _data_dwn_32_302__AEE_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 375M Nov 26 14:25 _data_dwn_32_302__AEP_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 170M Nov 26 14:25 _data_dwn_32_302__AES_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 227M Nov 26 14:25 _data_dwn_32_302__AFL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 501M Nov 26 14:26 _data_dwn_32_302__AIG_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 155M Nov 26 14:26 _data_dwn_32_302__AIV_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users  98M Nov 26 14:26 _data_dwn_32_302__AIZ_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 151M Nov 26 14:26 _data_dwn_32_302__AJG_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 294M Nov 26 14:26 _data_dwn_32_302__AKAM_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 167M Nov 26 14:26 _data_dwn_32_302__ALB_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 208M Nov 26 14:26 _data_dwn_32_302__ALGN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 185M Nov 26 14:26 _data_dwn_32_302__ALK_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 246M Nov 26 14:26 _data_dwn_32_302__ALL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 102M Nov 26 14:26 _data_dwn_32_302__ALLE_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 264M Nov 26 14:26 _data_dwn_32_302__ALXN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 976M Nov 26 14:26 _data_dwn_32_302__AMAT_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 1.1G Nov 26 14:26 _data_dwn_32_302__AMD_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 171M Nov 26 14:26 _data_dwn_32_302__AME_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 111M Nov 26 14:26 _data_dwn_32_302__AMG_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 451M Nov 26 14:27 _data_dwn_32_302__AMGN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users 188M Nov 26 14:27 _data_dwn_32_302__AMP_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users
_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__VNO_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__VRSK_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__VRSN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__VRTX_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__VZ_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WAB_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WAT_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WBA_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WCG_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WFC_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WHR_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WLTW_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WM_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WMB_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WMT_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WRB_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WRK_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WU_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WY_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__WYNN_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XEC_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XEL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLB_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLE_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLI_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLNX_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLP_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLV_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XLY_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XOM_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XRX_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__XYL_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__YUM_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__ZBH_2017-01-01_2017-12-31_10.7z
# -r-x------  1 kang flair-users    0 Nov 26 14:40 _data_dwn_32_302__ZION_2017-01-01_2017-12-31_10.7z
# -rw-------  1 kang flair-users 6.4M Nov 26 14:40 data.zip
# drwxr-sr-x  4 kang flair-users   48 Feb 12 13:06 FITB_data
# -rw-------  1 kang flair-users 1.1G Nov 26 14:41 kang@flair-node-01.robots.ox.ac.uk
# drwxr-sr-x  4 kang flair-users   48 Feb 12 13:04 MGM_data
# -rw-------  1 kang flair-users 1.7G Nov 26 14:41 out_disjoint15.tar.gz
# -rw-------  1 kang flair-users 199M Nov 26 14:41 out_ols_overlap15_numba.tar.gz
# -rw-------  1 kang flair-users 1.7G Nov 26 14:42 out_overlap15.tar.gz
# -rw-------  1 kang flair-users 1.1G Nov 26 14:42 out_overlap5.tar.gz
# -rw-r--r--  1 kang flair-users 1.5K Feb 12 12:42 run12feb.sh
# -rw-r--r--  1 kang flair-users 1.6K Feb 12 13:06 run12febv2.sh
# -rw-r--r--  1 kang flair-users 1.5K Jan 21 11:06 run21Jan.sh
# -rw-r--r--  1 kang flair-users 1.4K Dec  7 09:31 run3.sh
# -rw-r--r--  1 kang flair-users 1.4K Jan 21 10:54 runJan.sh
# -rw-r--r--  1 kang flair-users 1.2K Nov 26 14:36 run.sh
# drwxr-sr-x 12 kang        3509 4.0K Feb 12 12:49 SP500

# %%
# %%bash
# docker build --build-arg UID=$UID --build-arg GIT_TOKEN=$GIT_TOKEN -t d345fn01 .
# docker run --name d345fn01 --user $(id -u) -v $(pwd):/homes/80/kang -it --gpus '"device=3,4,5"' d345fn01
# docker run -it -v /scratch/local/kang:/data d345fn01

# %%
# %%bash
# cd /data
# touch run12feb.sh
# cat > run12feb.sh << 'EOF'
# input_dir="/data/" # Directory containing .7z files
# sp500_dir="/homes/80/kang/SP500/" # Directory to store all stock data directories
#
# # Define a list of stock names
# declare -a stock_list=('AAPL' 'MGM' 'FITB' 'MPC' 'GS' 'AEP' 'HP' 'KLAC' 'GPN' 'ROK')
#
# # Iterate over each .7z file in the input directory
# for file in "$input_dir"/*.7z; do
#     # Extract the stock name from the file name
#     stock_name=$(echo "$file" | grep -oP '(?<=__)\w+(?=_)')
#
#     # Check if the extracted stock name is in the list
#     if [[ " ${stock_list[@]} " =~ " ${stock_name} " ]]; then
#         # Create directories for the stock data and its subdirectories
#         stock_dir="${sp500_dir}${stock_name}_data"
#         mkdir -p "$stock_dir/Book_10" "$stock_dir/Flow_10"
#
#         # Unzip the file into a temporary directory
#         temp_dir=$(mktemp -d)
#         7z x "$file" -o"$temp_dir"
#
#         # Move files to appropriate subdirectories
#         for csv_file in "$temp_dir"/*.csv; do
#             if [[ $csv_file == *"orderbook"* ]]; then
#                 mv "$csv_file" "$stock_dir/Book_10/"
#             elif [[ $csv_file == *"message"* ]]; then
#                 mv "$csv_file" "$stock_dir/Flow_10/"
#             fi
#         done
#
#         # Remove the temporary directory
#         rm -r "$temp_dir"
#
#         # Move the stock directory into the SP500 directory
#         # mv "$stock_dir" "$sp500_dir/" # This line is not needed since "$stock_dir" already includes "$sp500_dir"
#     fi
# done
# EOF

# %%
# %%bash
# # cd /data
# touch run12feb.sh
# cat > run12feb.sh << 'EOF'
# input_dir="/homes/80/kang/scratch_local/" # Directory containing .7z files
# # input_dir="/data/" # Directory containing .7z files
# sp500_dir="/homes/80/kang/SP500/" # Directory to store all stock data directories
#
# # Define a list of stock names
# declare -a stock_list=('GPC')
#
# # Iterate over each .7z file in the input directory
# for file in "$input_dir"/*.7z; do
#     # Extract the stock name from the file name
#     stock_name=$(echo "$file" | grep -oP '(?<=__)\w+(?=_)')
#
#     # Check if the extracted stock name is in the list
#     if [[ " ${stock_list[@]} " =~ " ${stock_name} " ]]; then
#         # Create directories for the stock data and its subdirectories
#         stock_dir="${sp500_dir}${stock_name}_data"
#         mkdir -p "$stock_dir/Book_10" "$stock_dir/Flow_10"
#
#         # Unzip the file into a temporary directory
#         temp_dir=$(mktemp -d)
#         7z x "$file" -o"$temp_dir"
#
#         # Move files to appropriate subdirectories
#         for csv_file in "$temp_dir"/*.csv; do
#             if [[ $csv_file == *"orderbook"* ]]; then
#                 mv "$csv_file" "$stock_dir/Book_10/"
#             elif [[ $csv_file == *"message"* ]]; then
#                 mv "$csv_file" "$stock_dir/Flow_10/"
#             fi
#         done
#
#         # Remove the temporary directory
#         rm -r "$temp_dir"
#
#         # Move the stock directory into the SP500 directory
#         # mv "$stock_dir" "$sp500_dir/" # This line is not needed since "$stock_dir" already includes "$sp500_dir"
#     fi
# done
# EOF

# %%
bash ./run12feb.sh

# %%
# %%bash
# # cd /homes/80/kang/SP500/
# cd /scratch/local/kang/SP500
# ls -lh
# Out:
# total 0
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:43 AAPL_data
# drwxr-sr-x 4 kang 3509 36 Feb 12 12:46 AEP_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:47 FITB_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:48 GPN_data
# drwxr-sr-x 4 kang 3509 36 Feb 12 12:48 GS_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:49 HP_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:49 KLAC_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:49 MGM_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:49 MPC_data
# drwxr-sr-x 4 kang 3509 48 Feb 12 12:49 ROK_data

# %%
(base) kang@flair-node-01:/scratch/local/kang/SP500$ du -lh
7.6G    ./AEP_data/Book_10
1.6G    ./AEP_data/Flow_10
9.2G    ./AEP_data
7.0G    ./GS_data/Book_10
1.4G    ./GS_data/Flow_10
8.4G    ./GS_data
16G     ./FITB_data/Book_10
3.0G    ./FITB_data/Flow_10
19G     ./FITB_data
0       ./HP_data/Book_10
0       ./HP_data/Flow_10
0       ./HP_data
2.7G    ./GPN_data/Book_10
579M    ./GPN_data/Flow_10
3.3G    ./GPN_data
0       ./KLAC_data/Book_10
0       ./KLAC_data/Flow_10
0       ./KLAC_data
54G     ./AAPL_data/Book_10
11G     ./AAPL_data/Flow_10
64G     ./AAPL_data
0       ./MGM_data/Book_10
0       ./MGM_data/Flow_10
0       ./MGM_data
0       ./MPC_data/Book_10
0       ./MPC_data/Flow_10
0       ./MPC_data
0       ./ROK_data/Book_10
0       ./ROK_data/Flow_10
0       ./ROK_data
103G    .

# %%
lst = ['AEP','GS','FITB','GPN','AAPL']

# %%
path = '/scratch/local/kang/SP500'

# %% [markdown]
# ## new code

# %%
import ray
ray.shutdown()
ray.init(num_cpus = 40, object_store_memory = 60 * 10**9)
# ray.init(num_cpus = 40, object_store_memory = 100 * 10**9)
@ray.remote
def get_result(ob, msg, date, carry):
    try:
        symbol, VWAPs,ORACLEs,RMs,TWAPs = carry
        import gc
        import pandas as pd
        # prepare ob msg  
        msg.columns = ['time', 'type', 'id', 'qty', 'price', 'direct', 'remark']  
        # df  
        df = pd.concat([msg, ob], axis=1)  
        df.time *= 1e9  
        df.time = df.time.apply(pd.to_datetime)  
        df.time = df.time.dt.time  
        df['shorten_time'] = pd.to_datetime(df['time'].apply(lambda x:str(x).split('.')[0]), format='%H:%M:%S').dt.strftime('%H%M').astype(str)  
        # df['shorten_time'] = pd.to_datetime(df['time'], format='%H:%M:%S.%f').dt.strftime('%H%M').astype(str)  
        df = df[(df['shorten_time'] >= '0930') & (df['shorten_time'] < '1600')]  
        # truncate
        mean = df[[f'bid_price_{i}' for i in range(10)]].mean().mean() 
        # mean = df[[f'bid_price_{i}' for i in range(5)]].mean().mean() 
        mean_ceilling = mean * 10
        mean_bottom = mean * 0.1
        for i in range(10):
            df=df[(mean_bottom<=df[f'bid_price_{i}']) & (df[f'bid_price_{i}']<=mean_ceilling)]

        g=df.groupby('shorten_time')
        lst = []
        for idx, itm in g: 
            itm['order_flow_volume_1min'] = itm[itm['type']==4]['qty'].sum()
            lst.append(itm)
        df=pd.concat(lst)

        # task  
        df['trading_volume'] = df[df.type == 4].qty.sum()  
        task_ratio = 0.05  
        df['task_volume'] = (df.trading_volume * task_ratio).apply(int)  
        # dfa  
        dfa = df.drop_duplicates('shorten_time', keep='last')  

        # bin_time
        # Function to round time to the nearest 15-minute bin
        def round_time_to_nearest_15min(dt):
            # Round down to the nearest hour
            rounded_hour = dt.floor('H')
            # Find the minutes part of the datetime
            minutes = dt.minute
            # Determine the bin by dividing the minutes by 15, taking the floor, and multiplying back by 15
            bin_minutes = (minutes // 15) * 15
            # Return the rounded hour plus the binned minutes, setting seconds and microseconds to 0
            return rounded_hour + pd.Timedelta(minutes=bin_minutes)
        # Apply the rounding function to the 'time' column to create the 'bin_time' column
        dfa['bin_time'] =  pd.to_datetime(dfa['time'], format='%H:%M:%S.%f').apply(round_time_to_nearest_15min).dt.strftime('%H%M')
        dfa.reset_index(inplace=True,drop=True)

        # order_flow_volume_15min
        g=dfa.groupby('bin_time')
        lst = []
        for idx, itm in g: 
            itm['order_flow_volume_15min'] = itm['order_flow_volume_1min'].sum()
            lst.append(itm)
        dfa=pd.concat(lst)


        # rm  
        def get_aligned_values(VWAPs):  
            vwap = VWAPs[symbol].loc[date, :]  
            vwap = vwap.reset_index()  
            vwap.timeHMs = vwap.timeHMs.astype(int).astype(str).apply(lambda x: x.zfill(4))  
            vwap.drop('level_0', axis=1, inplace=True)  
            time_df = pd.DataFrame(df.shorten_time.unique(), columns=['timeHMs'])  
            dfb = pd.merge(vwap, time_df, how='right', on='timeHMs')  
            dfb.fillna(method='ffill', inplace=True)  
            return dfb.iloc[:, -1].to_numpy()  

        # jax  
        import jax  
        import jax.numpy as jnp  

        @jax.jit  
        def hamilton_apportionment_permuted_jax(votes, seats, key):  
            init_seats, remainders = jnp.divmod(votes, jnp.sum(votes) / seats)  # std_divisor = jnp.sum(votes) / seats  
            remaining_seats = jnp.array(seats - init_seats.sum(), dtype=jnp.int32)  # in {0,1,2,3}  

            def f(carry, x):  
                key, init_seats, remainders = carry  
                key, subkey = jax.random.split(key)  
                chosen_index = jax.random.choice(subkey, remainders.size, p=(remainders == remainders.max()) / (remainders == remainders.max()).sum())  
                return (key, init_seats.at[chosen_index].add(jnp.where(x < remaining_seats, 1, 0)), remainders.at[chosen_index].set(0)), x  

            (key, init_seats, remainders), x = jax.lax.scan(f, (key, init_seats, remainders), xs=jnp.arange(votes.shape[0]))  
            return init_seats.astype(jnp.int32)  

        rng = jax.random.PRNGKey(0)  
        rng, key = jax.random.split(rng, 2)  

        # dfa with task info  
        dfa['vwap'] = hamilton_apportionment_permuted_jax(get_aligned_values(VWAPs), dfa.task_volume.iloc[0], key)  
        dfa['oracle'] = hamilton_apportionment_permuted_jax(get_aligned_values(ORACLEs), dfa.task_volume.iloc[0], key)  
        dfa['order_flow_1min'] = hamilton_apportionment_permuted_jax(dfa['order_flow_volume_1min'].to_numpy(), dfa.task_volume.iloc[0], key)  
        dfa['order_flow_15min'] = hamilton_apportionment_permuted_jax(dfa['order_flow_volume_15min'].to_numpy(), dfa.task_volume.iloc[0], key)  
        dfa['rm'] = hamilton_apportionment_permuted_jax(get_aligned_values(RMs), dfa.task_volume.iloc[0], key)  
        dfa['twap'] = hamilton_apportionment_permuted_jax(get_aligned_values(TWAPs), dfa.task_volume.iloc[0], key)  

        # revenue
        def f(x, string):
            qty = x[string]
            levels = [(f'bid_price_{i}', f'bid_qty_{i}') for i in range(10)]
            revenue, accumulated_qty = 0, 0
            
            for level_price, level_qty in levels:
                if qty <= accumulated_qty + x[level_qty]:
                    revenue = revenue + (qty - accumulated_qty) * x[level_price]
                    break
                revenue += x[level_qty] * x[level_price]
                accumulated_qty += x[level_qty]
            return revenue


        for s in ['vwap','oracle','order_flow_1min','order_flow_15min','rm','twap']:
        # for s in ['vwap','oracle','rm','twap']:
            dfa[s+'_revenue'] = dfa.apply(lambda x: f(x,s),axis=1)

        # results  
        dfs = dfa.sum()  
        vwap_advantage = (dfs.vwap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        oracle_advantage = (dfs.oracle_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        order_flow_1min_advantage = (dfs.order_flow_1min_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        order_flow_15min_advantage = (dfs.order_flow_15min_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        twap_advantage = (dfs.twap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        # result = [date, vwap_advantage, oracle_advantage, twap_advantage]   
        result = [date, vwap_advantage, oracle_advantage, order_flow_1min_advantage, order_flow_15min_advantage, twap_advantage]  
         
        del msg, ob, dfa, df, dfs, g, lst
        gc.collect()
 
        return result
    except Exception as e:
        print(f"Error reading {symbol} on {date}: {e}")
# Out:
# 2024-02-25 08:59:24,204	INFO worker.py:1724 -- Started a local Ray instance.

# %%
from os import listdir  
from tqdm import tqdm  
import pandas as pd  
import numpy as np
import warnings
pd.options.mode.chained_assignment = None  # default='warn'
warnings.simplefilter(action='ignore', category=FutureWarning)

def data_alignment(ATFolder):
    '''
    The logic here is to load the three dir: messages data, rolling mean and vwap
    Then find the common_dates of all these three,
    Then pass into the init of the base env, 
    To only load the data window in the common dates.
    But we should also align the symbols, it has been done, as we will pass symbols 
    into the load_forecasted_and_original_volume_VWAP and load_forecasted_volume_RM
    '''
    def load_forecasted_and_original_volume_VWAP(symbol):
        import pandas as pd
        import numpy as np
        dir = '/homes/80/kang/cmem/output/0900_r_output_with_features_csv_fractional_shares_clipped_vwap/'
        df = pd.read_csv(dir+f'{symbol}.csv',index_col=0)
        df['symbol'] = symbol
        from datetime import datetime, timedelta
        timeHMs = np.array([int((datetime(2023, 1, 1, 9, 30) + i * timedelta(minutes=15)).strftime('%H%M')) for i in range(26)])
        timeHMs = np.tile(timeHMs, (1, int(df.shape[0]/timeHMs.shape[0]))).squeeze()
        df['timeHMs'] = timeHMs
        df = df[['date', 'timeHMs', 'x', 'qty', 'symbol']]
        d = df[['date', 'timeHMs', 'x']].pivot(index = 'date', columns = 'timeHMs')
        f = df[['date', 'timeHMs', 'qty']].pivot(index = 'date', columns = 'timeHMs')
        return d, f # x, qty

    def load_forecasted_volume_RM(symbol):
        import pandas as pd
        import numpy as np
        dir = '/homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/'
        df = pd.read_csv(dir+f'{symbol}.csv',index_col=0)
        df.columns = ['date', 'timeHMs', 'timeHMe', 'x_rm', 'symbol']
        df.date = df.date.apply(lambda d: str(d)[:4]+'-'+str(d)[4:6]+'-'+str(d)[6:8]) if len(str(df.date[0])) == 8 else df.date
        d = df[['date', 'timeHMs', 'x_rm']].pivot(index = 'date', columns = 'timeHMs')
        d = d.fillna(method = "ffill")
        return d # x

    def load_files(symbol):
        alphatradePath = ATFolder
        # alphatradePath = f"{ATFolder}/{symbol}_data"
        messagePath = alphatradePath+"/Flow_10/"
        orderbookPath = alphatradePath+"/Book_10/"
        from os import listdir; from os.path import isfile, join; import pandas as pd
        readFromPath = lambda data_path: sorted([f for f in listdir(data_path) if isfile(join(data_path, f))])
        messageFiles, orderbookFiles = readFromPath(messagePath), readFromPath(orderbookPath)
        message_dates = np.array([m[4:14] for m in messageFiles])
        message_dates = np.array([m.split("_")[1] for m in messageFiles])
        return message_dates
    
    def get_symbols():
        from os.path import isdir
        from os import listdir
        path_dir1 = '/homes/80/kang/cmem/output/0900_r_output_with_features_csv_fractional_shares_clipped_vwap/'
        path_dir2 = ATFolder
        symbols1 = np.array([dirname.split(".")[0] for dirname in listdir(path_dir1)])
        symbols2 = np.array([path_dir2.split("_")[0].split("/")[-1]])
        # symbols2 = np.array([dirname.split("_")[0] for dirname in listdir(path_dir2) 
        #             if isdir(os.path.join(path_dir2, dirname))])
        intersection = np.intersect1d(symbols1, symbols2)
        return intersection
    common_stocks = get_symbols()
    assert len(common_stocks) >= 1
    
    def get_raw_VWAPs_ORACLEs_RMs():
        ds = [(symbol, *load_forecasted_and_original_volume_VWAP(symbol)) for symbol in common_stocks]
        VWAPs = [(d[0], d[1]) for d in ds]
        ORACLEs = [(d[0], d[2]) for d in ds]
        RMs = [(symbol, load_forecasted_volume_RM(symbol)) for symbol in common_stocks]
        return VWAPs, ORACLEs, RMs
    VWAPs, ORACLEs, RMs = get_raw_VWAPs_ORACLEs_RMs()
    
    def get_common_dates():
        dates_vwap =  VWAPs[-1][-1].index.to_numpy()
        dates_rm =  RMs[-1][-1].index.to_numpy()
        message_dates = load_files(common_stocks[-1]) 
        common_dates = np.intersect1d(np.intersect1d(dates_vwap, message_dates),dates_rm)
        return common_dates
    common_dates = get_common_dates()
    
    def align_dates(Xs):
        Xs = {d[0]: d[1].loc[common_dates] for d in Xs}
        return Xs
    VWAPs, ORACLEs, RMs = list(map(align_dates, [VWAPs, ORACLEs, RMs]))

    def generate_TWAPs(RMs):
        def f(df):
            dff = df.copy()
            dff.loc[:, :] = 1
            return dff
        return {symbol: f(df) for symbol, df in RMs.items()}
    TWAPs = generate_TWAPs(RMs)
            
    return common_dates, common_stocks, VWAPs, ORACLEs, RMs, TWAPs


def do_computation(symbol): 
    import gc
    # lst = ['AEP','GS','FITB','GPN','AAPL']
    # ['AAL','ABC','ABT','ADBE','CHD','AAP','ABBV','ABMD','ACN','BAC','CLX']
    # symbol = 'GPC' 
    # symbol = 'AAPL' 
    # symbol = 'GPN'
    # symbol = 'GS'
    # symbol = 'FITB'
    # symbol = 'AEP'
    
    ATFolder = f"/homes/80/kang/SP500/{symbol}_data"  
    # ATFolder = f"/scratch/local/kang/SP500/{symbol}_data"  
    common_dates, common_stocks, VWAPs, ORACLEs, RMs, TWAPs = data_alignment(ATFolder)  
    ob_columns = sum([[f'ask_price_{i}',f'ask_qty_{i}',f'bid_price_{i}',f'bid_qty_{i}'] for i in range(10)] , [])
    msg_columns = ['time', 'type', 'id', 'qty', 'price', 'direct', 'remark'] 
    # obs = [pd.read_csv(ATFolder + "/Book_10/" + file, header=None, names = ob_columns) for file in tqdm(listdir(ATFolder + "/Book_10/"))]  
    # msgs = [pd.read_csv(ATFolder + "/Flow_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Flow_10/"))]  
    # obs = [pd.read_csv(ATFolder + "/Book_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Book_10/")[:2])]  
    # msgs = [pd.read_csv(ATFolder + "/Flow_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Flow_10/")[:2])]  
    lobster_dates = [file.split("_")[1] for file in listdir(ATFolder + "/Book_10/")]
    dates = np.intersect1d(common_dates, lobster_dates)
    len(dates)

    # @ray.remote(num_cpus=20)
    # @ray.remote(num_cpus=40, memory=80*10**9)
    @ray.remote(num_cpus=20, memory=40*10**9)
    def read_csv_obs(file): return {file.split('_')[1]: pd.read_csv(ATFolder + "/Book_10/" + file, header=None, names=ob_columns)}
    obs = [ray.get(f) for f in tqdm([read_csv_obs.remote(file) for file in listdir(ATFolder + "/Book_10/") if file.split('_')[1] in dates])]
    # obs = [ray.get(f) for f in tqdm([read_csv_obs.remote(file) for file in listdir(ATFolder + "/Book_10/")])]
    # @ray.remote(num_cpus=40, memory=80*10**9)
    @ray.remote(num_cpus=20, memory=40*10**9)
    def read_csv_msgs(file): return {file.split('_')[1]: pd.read_csv(ATFolder + "/Flow_10/" + file, header=None, names=msg_columns)}
    msgs = [ray.get(f) for f in tqdm([read_csv_msgs.remote(file) for file in listdir(ATFolder + "/Flow_10/") if file.split('_')[1] in dates])]


    from collections import ChainMap
    msgs = dict(ChainMap(*msgs))
    obs = dict(ChainMap(*obs))
    assert len(obs) == len(msgs)  
    
    ids = [get_result.remote(obs[date], msgs[date], date, (symbol,VWAPs,ORACLEs,RMs,TWAPs)) for date in tqdm(dates)]
    len(ids)
    
    results = [ray.get(idx) for idx in tqdm(ids)]    
    
    len(results)
    results_ = [result for result in results if result != None]
    len(results_)
        
    dff = pd.DataFrame(results_, columns=['date', 'vwap_advantage', 'oracle_advantage', 'order_flow_1min_advantage', 'order_flow_15min_advantage','twap_advantage'])
    print("symbol:",symbol)
    print("dff.mean():\n",dff.mean())
    
    del msgs, obs, ids, results, results_
    gc.collect()
    
    return {symbol:dff}
# do_computation(symbol)
# for symbol in []:
#     do_computation(symbol)
results = [do_computation(symbol) for symbol in tqdm(['AAL','ABC','ABT','ADBE','CHD','AAP','ABBV','ABMD','ACN','BAC','CLX'])]
# Out:
# 100%|██████████| 109/109 [00:19<00:00,  5.65it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# (read_csv_msgs pid=1950765) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#
#
#
#
#
#
#
#
#
#
#
#
# (read_csv_msgs pid=1950765) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#
#
#
#
#  35%|███▍      | 38/109 [00:02<00:03, 17.78it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 109/109 [00:04<00:00, 21.82it/s]
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
#
# 100%|██████████| 109/109 [00:03<00:00, 29.22it/s]
#
#
#
#
# (get_result pid=1956501) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=1956501) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=1956501) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=1956501)
# (get_result pid=1956501) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (read_csv_msgs pid=1950765) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False. [repeated 3x across cluster]
# (get_result pid=1956501) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=1956501) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (get_result pid=1956463) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 15x across cluster]
# (get_result pid=1956463) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 15x across cluster]
# (get_result pid=1956463) Try using .loc[row_indexer,col_indexer] = value instead [repeated 15x across cluster]
# (get_result pid=1956463)  [repeated 15x across cluster]
# (get_result pid=1956463) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 15x across cluster]
# (get_result pid=1956423) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 17x across cluster]
# (get_result pid=1956777) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 16x across cluster]
#
#
#
#
# (get_result pid=1957075) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 19x across cluster]
# (get_result pid=1957075) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 19x across cluster]
# (get_result pid=1957075) Try using .loc[row_indexer,col_indexer] = value instead [repeated 19x across cluster]
# (get_result pid=1957075)  [repeated 19x across cluster]
# (get_result pid=1957075) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 19x across cluster]
# (get_result pid=1957075) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 17x across cluster]
# (get_result pid=1957075) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 18x across cluster]
#
#
#
#
# (get_result pid=1957168) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 6x across cluster]
# (get_result pid=1957168) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 6x across cluster]
# (get_result pid=1957168) Try using .loc[row_indexer,col_indexer] = value instead [repeated 6x across cluster]
# (get_result pid=1957168)  [repeated 6x across cluster]
# (get_result pid=1957168) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 6x across cluster]
#
#
#
#
# (get_result pid=1957373) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 5x across cluster]
# (get_result pid=1957168) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 6x across cluster]
#
#
#
#
#
#
#
#
# (get_result pid=1958194) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 21x across cluster]
# (get_result pid=1958194) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 21x across cluster]
# (get_result pid=1958194) Try using .loc[row_indexer,col_indexer] = value instead [repeated 21x across cluster]
# (get_result pid=1958194)  [repeated 21x across cluster]
# (get_result pid=1958194) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 21x across cluster]
#
#
#
#
# (get_result pid=1950764) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 25x across cluster]
#
#
#
#
#
#
#
#
# (get_result pid=1956444) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 22x across cluster]
# (get_result pid=1956444) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 22x across cluster]
# (get_result pid=1956444) Try using .loc[row_indexer,col_indexer] = value instead [repeated 22x across cluster]
# (get_result pid=1956444)  [repeated 22x across cluster]
# (get_result pid=1956444) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 22x across cluster]
#
#
#
#
# (get_result pid=1956476) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 22x across cluster]
# (get_result pid=1956777) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 17x across cluster]
# (get_result pid=1956777) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 17x across cluster]
# (get_result pid=1956777) Try using .loc[row_indexer,col_indexer] = value instead [repeated 17x across cluster]
# (get_result pid=1956777)  [repeated 17x across cluster]
# (get_result pid=1956777) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 17x across cluster]
#
#
#
#
#
#
#
#
# (get_result pid=1957181) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 18x across cluster]
#
#
#
#
#
#
#
#
# 100%|██████████| 109/109 [00:40<00:00,  2.66it/s]
# symbol: AAL
#   0%|          | 0/109 [03:36<?, ?it/s]
#   0%|          | 0/11 [04:20<?, ?it/s]
# dff.mean():
#  vwap_advantage               -1.903330
# oracle_advantage              0.586819
# order_flow_1min_advantage    -6.566805
# order_flow_15min_advantage   -0.052237
# twap_advantage                0.814786
# dtype: float64
# 100%|██████████| 109/109 [00:07<00:00, 14.02it/s]
# 100%|██████████| 109/109 [00:02<00:00, 38.83it/s]
# 100%|██████████| 109/109 [00:00<00:00, 184.57it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=1957577) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 9x across cluster]
# (get_result pid=1957577) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 9x across cluster]
# (get_result pid=1957577) Try using .loc[row_indexer,col_indexer] = value instead [repeated 9x across cluster]
# (get_result pid=1957577)  [repeated 9x across cluster]
# (get_result pid=1957577) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 9x across cluster]
# (get_result pid=1950764) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 3x across cluster]
#   1%|          | 1/109 [00:03<05:44,  3.19s/it](get_result pid=1981975) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
#   9%|▉         | 10/109 [00:05<00:32,  3.04it/s](get_result pid=1957577) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 41x across cluster]
# (get_result pid=1957577) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 41x across cluster]
# (get_result pid=1957577) Try using .loc[row_indexer,col_indexer] = value instead [repeated 41x across cluster]
# (get_result pid=1957577)  [repeated 41x across cluster]
# (get_result pid=1957577) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 41x across cluster]
# (get_result pid=1982297) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 34x across cluster]
#  11%|█         | 12/109 [00:07<00:44,  2.16it/s](get_result pid=1982026) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 37x across cluster]
#  61%|██████▏   | 67/109 [00:10<00:03, 11.02it/s](get_result pid=1982239) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 39x across cluster]
# (get_result pid=1982239) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 39x across cluster]
# (get_result pid=1982239) Try using .loc[row_indexer,col_indexer] = value instead [repeated 39x across cluster]
# (get_result pid=1982239)  [repeated 39x across cluster]
# (get_result pid=1982239) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 39x across cluster]
# (get_result pid=1982433) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 43x across cluster]
# 100%|██████████| 109/109 [00:15<00:00,  7.03it/s]
# symbol: ABC
# dff.mean():
#  vwap_advantage               -3.374709
# oracle_advantage             -5.351921
# order_flow_1min_advantage    -3.910911
# order_flow_15min_advantage   -3.715139
# twap_advantage               -0.186915
# dtype: float64
# 100%|██████████| 109/109 [00:20<00:00,  5.32it/s]
#  42%|████▏     | 46/109 [00:03<00:03, 16.04it/s](read_csv_msgs pid=1982329) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# (get_result pid=1981924) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 28x across cluster]
# (get_result pid=1981924) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 28x across cluster]
# (get_result pid=1981924) Try using .loc[row_indexer,col_indexer] = value instead [repeated 28x across cluster]
# (get_result pid=1981924)  [repeated 28x across cluster]
# (get_result pid=1981924) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 28x across cluster]
# (get_result pid=1981924) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 32x across cluster]
# 100%|██████████| 109/109 [00:06<00:00, 16.21it/s]
# 100%|██████████| 109/109 [00:01<00:00, 86.03it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](read_csv_msgs pid=1981924) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# (get_result pid=2006684) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2006684) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2006684) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2006684)
# (get_result pid=2006684) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2006559) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2006559) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2006559) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2006559)
# (get_result pid=2006559) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2006684) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2006684) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   1%|          | 1/109 [00:08<14:31,  8.07s/it](get_result pid=2007456) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 32x across cluster]
# (get_result pid=2007456) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 32x across cluster]
# (get_result pid=2007456) Try using .loc[row_indexer,col_indexer] = value instead [repeated 32x across cluster]
# (get_result pid=2007456)  [repeated 32x across cluster]
# (get_result pid=2007456) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 32x across cluster]
# (get_result pid=2006482) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 29x across cluster]
# (get_result pid=2006747) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 29x across cluster]
#   4%|▎         | 4/109 [00:12<03:51,  2.21s/it](get_result pid=2006892) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 11x across cluster]
# (get_result pid=2006892) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 11x across cluster]
# (get_result pid=2006892) Try using .loc[row_indexer,col_indexer] = value instead [repeated 11x across cluster]
# (get_result pid=2006892)  [repeated 11x across cluster]
# (get_result pid=2006892) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 11x across cluster]
# (get_result pid=2006463) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 8x across cluster]
#   6%|▌         | 6/109 [00:15<03:21,  1.96s/it](get_result pid=2007836) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 17x across cluster]
#  42%|████▏     | 46/109 [00:19<00:14,  4.32it/s](get_result pid=2006495) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 24x across cluster]
# (get_result pid=2006495) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 24x across cluster]
# (get_result pid=2006495) Try using .loc[row_indexer,col_indexer] = value instead [repeated 24x across cluster]
# (get_result pid=2006495)  [repeated 24x across cluster]
# (get_result pid=2006495) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 24x across cluster]
# (get_result pid=2006684) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 24x across cluster]
# (get_result pid=2006592) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 21x across cluster]
# (get_result pid=2006592) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 21x across cluster]
# (get_result pid=2006592) Try using .loc[row_indexer,col_indexer] = value instead [repeated 21x across cluster]
# (get_result pid=2006592)  [repeated 21x across cluster]
# (get_result pid=2006592) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 21x across cluster]
# (get_result pid=2007576) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 20x across cluster]
#  85%|████████▌ | 93/109 [00:29<00:02,  5.71it/s](get_result pid=2007166) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 18x across cluster]
# (get_result pid=2007166) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 18x across cluster]
# (get_result pid=2007166) Try using .loc[row_indexer,col_indexer] = value instead [repeated 18x across cluster]
# (get_result pid=2007166)  [repeated 18x across cluster]
# (get_result pid=2007166) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 18x across cluster]
#  91%|█████████ | 99/109 [00:31<00:02,  4.94it/s](get_result pid=2007699) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 18x across cluster]
# 100%|██████████| 109/109 [00:32<00:00,  3.37it/s]
# symbol: ABT
# dff.mean():
#  vwap_advantage               -1.006774
# oracle_advantage             -0.758981
# order_flow_1min_advantage    -1.531447
# order_flow_15min_advantage   -0.562389
# twap_advantage               -0.586578
# dtype: float64
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# symbol: ADBE
# dff.mean():
#  date                          NaN
# vwap_advantage                NaN
# oracle_advantage              NaN
# order_flow_1min_advantage     NaN
# order_flow_15min_advantage    NaN
# twap_advantage                NaN
# dtype: object
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# 0it [00:00, ?it/s]
# symbol: CHD
# dff.mean():
#  date                          NaN
# vwap_advantage                NaN
# oracle_advantage              NaN
# order_flow_1min_advantage     NaN
# order_flow_15min_advantage    NaN
# twap_advantage                NaN
# dtype: object
# 100%|██████████| 109/109 [00:09<00:00, 11.23it/s]
# 100%|██████████| 109/109 [00:03<00:00, 35.00it/s]
# 100%|██████████| 109/109 [00:00<00:00, 189.63it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=2007166) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 2x across cluster]
# (get_result pid=2007166) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 2x across cluster]
# (get_result pid=2007166) Try using .loc[row_indexer,col_indexer] = value instead [repeated 2x across cluster]
# (get_result pid=2007166)  [repeated 2x across cluster]
# (get_result pid=2007166) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 2x across cluster]
# (get_result pid=2031049) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2007166) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#  15%|█▍        | 16/109 [00:05<00:13,  6.90it/s](get_result pid=2031358) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 42x across cluster]
# (get_result pid=2031358) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 42x across cluster]
# (get_result pid=2031358) Try using .loc[row_indexer,col_indexer] = value instead [repeated 42x across cluster]
# (get_result pid=2031358)  [repeated 42x across cluster]
# (get_result pid=2031358) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 42x across cluster]
# (get_result pid=2031184) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 35x across cluster]
# (get_result pid=2030960) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 43x across cluster]
#  71%|███████   | 77/109 [00:11<00:02, 12.91it/s](get_result pid=2031320) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 56x across cluster]
# (get_result pid=2031320) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 56x across cluster]
# (get_result pid=2031320) Try using .loc[row_indexer,col_indexer] = value instead [repeated 56x across cluster]
# (get_result pid=2031320)  [repeated 56x across cluster]
# (get_result pid=2031320) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 56x across cluster]
# (get_result pid=2031152) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 2x across cluster]
# (get_result pid=2030985) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 56x across cluster]
# 100%|██████████| 109/109 [00:16<00:00,  6.68it/s]
# symbol: AAP
# dff.mean():
#  vwap_advantage               -0.742033
# oracle_advantage              0.346790
# order_flow_1min_advantage     1.006242
# order_flow_15min_advantage    1.095633
# twap_advantage               -0.634349
# dtype: float64
# 100%|██████████| 109/109 [00:17<00:00,  6.40it/s]
#  21%|██        | 23/109 [00:01<00:05, 14.95it/s](read_csv_msgs pid=2031010) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# (get_result pid=2007699) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 10x across cluster]
# (get_result pid=2007699) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 10x across cluster]
# (get_result pid=2007699) Try using .loc[row_indexer,col_indexer] = value instead [repeated 10x across cluster]
# (get_result pid=2007699)  [repeated 10x across cluster]
# (get_result pid=2007699) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 10x across cluster]
# (get_result pid=2007699) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 9x across cluster]
# 100%|██████████| 109/109 [00:05<00:00, 18.88it/s]
# 100%|██████████| 109/109 [00:00<00:00, 128.46it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](read_csv_msgs pid=2007699) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False. [repeated 2x across cluster]
# (get_result pid=2055508) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2055508) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2055508) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2055508)
# (get_result pid=2055508) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2055598) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2055598) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2055598) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2055598)
# (get_result pid=2055598) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2055508) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2055508) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   3%|▎         | 3/109 [00:10<05:12,  2.95s/it](get_result pid=2056354) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 24x across cluster]
# (get_result pid=2056354) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 24x across cluster]
# (get_result pid=2056354) Try using .loc[row_indexer,col_indexer] = value instead [repeated 24x across cluster]
# (get_result pid=2056354)  [repeated 24x across cluster]
# (get_result pid=2056354) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 24x across cluster]
# (get_result pid=2055444) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 22x across cluster]
#   4%|▎         | 4/109 [00:11<03:57,  2.26s/it](get_result pid=2055985) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 23x across cluster]
#  15%|█▍        | 16/109 [00:14<00:41,  2.26it/s](get_result pid=2055463) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 16x across cluster]
# (get_result pid=2055463) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 16x across cluster]
# (get_result pid=2055463) Try using .loc[row_indexer,col_indexer] = value instead [repeated 16x across cluster]
# (get_result pid=2055463)  [repeated 16x across cluster]
# (get_result pid=2055463) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 16x across cluster]
# (get_result pid=2055750) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 13x across cluster]
#  19%|█▉        | 21/109 [00:16<00:36,  2.39it/s](get_result pid=2007699) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 18x across cluster]
#  32%|███▏      | 35/109 [00:19<00:21,  3.40it/s](get_result pid=2055750) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 34x across cluster]
# (get_result pid=2055750) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 34x across cluster]
# (get_result pid=2055750) Try using .loc[row_indexer,col_indexer] = value instead [repeated 34x across cluster]
# (get_result pid=2055750)  [repeated 34x across cluster]
# (get_result pid=2055750) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 34x across cluster]
# (get_result pid=2056023) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 2x across cluster]
#  38%|███▊      | 41/109 [00:21<00:19,  3.47it/s](get_result pid=2055750) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 33x across cluster]
#  84%|████████▍ | 92/109 [00:25<00:02,  7.73it/s](get_result pid=2055731) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 33x across cluster]
# (get_result pid=2055731) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 33x across cluster]
# (get_result pid=2055731) Try using .loc[row_indexer,col_indexer] = value instead [repeated 33x across cluster]
# (get_result pid=2055731)  [repeated 33x across cluster]
# (get_result pid=2055731) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 33x across cluster]
# (get_result pid=2055731) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 34x across cluster]
# 100%|██████████| 109/109 [00:27<00:00,  3.93it/s]
# symbol: ABBV
# dff.mean():
#  vwap_advantage               -1.866399
# oracle_advantage             -1.817647
# order_flow_1min_advantage    -2.665352
# order_flow_15min_advantage   -0.724264
# twap_advantage               -0.721602
# dtype: float64
# 100%|██████████| 109/109 [00:05<00:00, 20.83it/s]
# 100%|██████████| 109/109 [00:01<00:00, 63.89it/s]
# 100%|██████████| 109/109 [00:00<00:00, 258.02it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=2055731) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2055731) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2055731) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2055731)
# (get_result pid=2055731) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2055425) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2055425) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2055425) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2055425)
# (get_result pid=2055425) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2055731) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   1%|          | 1/109 [00:02<03:37,  2.01s/it](get_result pid=2079498) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
#  39%|███▉      | 43/109 [00:05<00:03, 16.67it/s](get_result pid=2079202) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 68x across cluster]
# (get_result pid=2079202) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 68x across cluster]
# (get_result pid=2079202) Try using .loc[row_indexer,col_indexer] = value instead [repeated 68x across cluster]
# (get_result pid=2079202)  [repeated 68x across cluster]
# (get_result pid=2079202) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 68x across cluster]
#  43%|████▎     | 47/109 [00:06<00:05, 11.68it/s](get_result pid=2079531) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 67x across cluster]
# (get_result pid=2079429) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 37x across cluster]
#  62%|██████▏   | 68/109 [00:07<00:02, 14.57it/s](get_result pid=2079484) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 39x across cluster]
# (get_result pid=2079484) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 39x across cluster]
# (get_result pid=2079484) Try using .loc[row_indexer,col_indexer] = value instead [repeated 39x across cluster]
# (get_result pid=2079484)  [repeated 39x across cluster]
# (get_result pid=2079484) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 39x across cluster]
# (get_result pid=2079157) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 40x across cluster]
# 100%|██████████| 109/109 [00:15<00:00,  7.07it/s]
# symbol: ABMD
# dff.mean():
#  vwap_advantage               -1.034934
# oracle_advantage             -1.410020
# order_flow_1min_advantage    -7.018110
# order_flow_15min_advantage    0.181022
# twap_advantage               -0.372054
# dtype: float64
# 100%|██████████| 109/109 [00:11<00:00,  9.80it/s]
# 100%|██████████| 109/109 [00:03<00:00, 31.37it/s]
# 100%|██████████| 109/109 [00:00<00:00, 181.36it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=2079157) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2079157) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2079157) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2079157)
# (get_result pid=2079157) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2079484) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (get_result pid=2102670) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2102670) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2102670) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2102670)
# (get_result pid=2102670) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2102670) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2079157) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#  37%|███▋      | 40/109 [00:08<00:05, 11.95it/s](get_result pid=2102753) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 39x across cluster]
# (get_result pid=2102753) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 39x across cluster]
# (get_result pid=2102753) Try using .loc[row_indexer,col_indexer] = value instead [repeated 39x across cluster]
# (get_result pid=2102753)  [repeated 39x across cluster]
# (get_result pid=2102753) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 39x across cluster]
# (get_result pid=2103064) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 37x across cluster]
# (get_result pid=2103064) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 39x across cluster]
#  73%|███████▎  | 80/109 [00:11<00:02, 13.93it/s](get_result pid=2102523) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 57x across cluster]
# (get_result pid=2102523) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 57x across cluster]
# (get_result pid=2102523) Try using .loc[row_indexer,col_indexer] = value instead [repeated 57x across cluster]
# (get_result pid=2102523)  [repeated 57x across cluster]
# (get_result pid=2102523) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 57x across cluster]
#  81%|████████  | 88/109 [00:14<00:02,  8.22it/s](get_result pid=2102523) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 58x across cluster]
# 100%|██████████| 109/109 [00:15<00:00,  6.98it/s]
# symbol: ACN
# dff.mean():
#  vwap_advantage               -0.939506
# oracle_advantage             -1.274510
# order_flow_1min_advantage    -0.150266
# order_flow_15min_advantage    0.163692
# twap_advantage               -0.118278
# dtype: float64
# 100%|██████████| 109/109 [00:53<00:00,  2.04it/s]
#   1%|          | 1/109 [00:00<00:21,  5.00it/s](read_csv_msgs pid=2102919) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
# (get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 11x across cluster]
# (get_result pid=2102919) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 11x across cluster]
# (get_result pid=2102919) Try using .loc[row_indexer,col_indexer] = value instead [repeated 11x across cluster]
# (get_result pid=2102919)  [repeated 11x across cluster]
# (get_result pid=2102919) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 11x across cluster]
# (get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 11x across cluster]
#   3%|▎         | 3/109 [00:00<00:14,  7.17it/s](read_csv_msgs pid=2102919) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False.
#  39%|███▊      | 42/109 [00:05<00:07,  8.74it/s](read_csv_msgs pid=2102817) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False. [repeated 37x across cluster]
#  75%|███████▌  | 82/109 [00:10<00:03,  6.87it/s](read_csv_msgs pid=2102817) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False. [repeated 39x across cluster]
# 100%|██████████| 109/109 [00:13<00:00,  7.86it/s]
# 100%|██████████| 109/109 [00:05<00:00, 18.80it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=2128124) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2128124) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2128124) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2128124)
# (get_result pid=2128124) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (read_csv_msgs pid=2102919) /tmp/ipykernel_1919902/1164114185.py:134: DtypeWarning: Columns (6) have mixed types. Specify dtype option on import or set low_memory=False. [repeated 21x across cluster]
# (get_result pid=2128124) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2128124) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (get_result pid=2127646) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 3x across cluster]
# (get_result pid=2127646) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 3x across cluster]
# (get_result pid=2127646) Try using .loc[row_indexer,col_indexer] = value instead [repeated 3x across cluster]
# (get_result pid=2127646)  [repeated 3x across cluster]
# (get_result pid=2127646) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 3x across cluster]
# (get_result pid=2127645) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 4x across cluster]
# (get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 4x across cluster]
#   2%|▏         | 2/109 [00:17<13:39,  7.66s/it](get_result pid=2129115) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 17x across cluster]
# (get_result pid=2129115) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 17x across cluster]
# (get_result pid=2129115) Try using .loc[row_indexer,col_indexer] = value instead [repeated 17x across cluster]
# (get_result pid=2129115)  [repeated 17x across cluster]
# (get_result pid=2129115) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 17x across cluster]
# (get_result pid=2129115) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 14x across cluster]
# (get_result pid=2128198) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 17x across cluster]
#   4%|▎         | 4/109 [00:21<06:57,  3.98s/it](get_result pid=2127703) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 13x across cluster]
# (get_result pid=2127703) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 13x across cluster]
# (get_result pid=2127703) Try using .loc[row_indexer,col_indexer] = value instead [repeated 13x across cluster]
# (get_result pid=2127703)  [repeated 13x across cluster]
# (get_result pid=2127703) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 13x across cluster]
# (get_result pid=2128217) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 12x across cluster]
#   6%|▌         | 6/109 [00:26<05:30,  3.21s/it](get_result pid=2127703) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 12x across cluster]
# (get_result pid=2129574) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 2x across cluster]
# (get_result pid=2129574) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 2x across cluster]
# (get_result pid=2129574) Try using .loc[row_indexer,col_indexer] = value instead [repeated 2x across cluster]
# (get_result pid=2129574)  [repeated 2x across cluster]
# (get_result pid=2129574) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 2x across cluster]
# (get_result pid=2129574) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 3x across cluster]
# (get_result pid=2128299) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 2x across cluster]
#  15%|█▍        | 16/109 [00:31<01:45,  1.14s/it](get_result pid=2129075) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 9x across cluster]
# (get_result pid=2129075) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 9x across cluster]
# (get_result pid=2129075) Try using .loc[row_indexer,col_indexer] = value instead [repeated 9x across cluster]
# (get_result pid=2129075)  [repeated 9x across cluster]
# (get_result pid=2129075) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 9x across cluster]
# (get_result pid=2128688) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 3x across cluster]
#  19%|█▉        | 21/109 [00:35<01:29,  1.02s/it](get_result pid=2127684) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 10x across cluster]
# (get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 12x across cluster]
# (get_result pid=2102919) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 12x across cluster]
# (get_result pid=2102919) Try using .loc[row_indexer,col_indexer] = value instead [repeated 12x across cluster]
# (get_result pid=2102919)  [repeated 12x across cluster]
# (get_result pid=2102919) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 12x across cluster]
#  30%|███       | 33/109 [00:39<00:50,  1.50it/s](get_result pid=2129443) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# (get_result pid=2129115) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 14x across cluster]
# (get_result pid=2127703) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 9x across cluster]
# (get_result pid=2127703) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 9x across cluster]
# (get_result pid=2127703) Try using .loc[row_indexer,col_indexer] = value instead [repeated 9x across cluster]
# (get_result pid=2127703)  [repeated 9x across cluster]
# (get_result pid=2127703) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 9x across cluster]
# (get_result pid=2127703) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 6x across cluster]
# (get_result pid=2129914) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 6x across cluster]
# (get_result pid=2129914) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 6x across cluster]
# (get_result pid=2129914) Try using .loc[row_indexer,col_indexer] = value instead [repeated 6x across cluster]
# (get_result pid=2129914)  [repeated 6x across cluster]
# (get_result pid=2129914) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 6x across cluster]
#  40%|████      | 44/109 [00:50<00:51,  1.27it/s](get_result pid=2129320) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 8x across cluster]
#  64%|██████▍   | 70/109 [00:54<00:16,  2.38it/s](get_result pid=2129574) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 8x across cluster]
# (get_result pid=2129574) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 8x across cluster]
# (get_result pid=2129574) Try using .loc[row_indexer,col_indexer] = value instead [repeated 8x across cluster]
# (get_result pid=2129574)  [repeated 8x across cluster]
# (get_result pid=2129574) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 8x across cluster]
#  70%|██████▉   | 76/109 [00:56<00:12,  2.55it/s](get_result pid=2129189) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 7x across cluster]
#  71%|███████   | 77/109 [00:59<00:16,  1.96it/s](get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 7x across cluster]
# (get_result pid=2102919) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 7x across cluster]
# (get_result pid=2102919) Try using .loc[row_indexer,col_indexer] = value instead [repeated 7x across cluster]
# (get_result pid=2102919)  [repeated 7x across cluster]
# (get_result pid=2102919) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 7x across cluster]
# (get_result pid=2102919) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 6x across cluster]
# (get_result pid=2129955) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 8x across cluster]
# (get_result pid=2129955) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 8x across cluster]
# (get_result pid=2129955) Try using .loc[row_indexer,col_indexer] = value instead [repeated 8x across cluster]
# (get_result pid=2129955)  [repeated 8x across cluster]
# (get_result pid=2129955) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 8x across cluster]
# (get_result pid=2129955) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 8x across cluster]
# (get_result pid=2129115) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 8x across cluster]
# (get_result pid=2129115) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 8x across cluster]
# (get_result pid=2129115) Try using .loc[row_indexer,col_indexer] = value instead [repeated 8x across cluster]
# (get_result pid=2129115)  [repeated 8x across cluster]
# (get_result pid=2129115) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 8x across cluster]
# (get_result pid=2129115) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 8x across cluster]
# (get_result pid=2128606) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 2x across cluster]
# (get_result pid=2128606) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 2x across cluster]
# (get_result pid=2128606) Try using .loc[row_indexer,col_indexer] = value instead [repeated 2x across cluster]
# (get_result pid=2128606)  [repeated 2x across cluster]
# (get_result pid=2128606) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 2x across cluster]
#  72%|███████▏  | 78/109 [01:16<00:50,  1.62s/it](get_result pid=2127928) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 3x across cluster]
# (get_result pid=2129009) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 2x across cluster]
# (get_result pid=2129009) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 2x across cluster]
# (get_result pid=2129009) Try using .loc[row_indexer,col_indexer] = value instead [repeated 2x across cluster]
# (get_result pid=2129009)  [repeated 2x across cluster]
# (get_result pid=2129009) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 2x across cluster]
#  83%|████████▎ | 90/109 [01:28<00:24,  1.29s/it](get_result pid=2128947) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 2x across cluster]
# (get_result pid=2127645) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 2x across cluster]
# (get_result pid=2127645) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 2x across cluster]
# (get_result pid=2127645) Try using .loc[row_indexer,col_indexer] = value instead [repeated 2x across cluster]
# (get_result pid=2127645)  [repeated 2x across cluster]
# (get_result pid=2127645) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 2x across cluster]
# 100%|██████████| 109/109 [01:45<00:00,  1.04it/s]
# symbol: BAC
# dff.mean():
#  vwap_advantage                0.753995
# oracle_advantage              0.721838
# order_flow_1min_advantage    -2.107184
# order_flow_15min_advantage   -0.007142
# twap_advantage                0.553338
# dtype: float64
# 100%|██████████| 109/109 [00:07<00:00, 14.48it/s]
# 100%|██████████| 109/109 [00:02<00:00, 37.65it/s]
# 100%|██████████| 109/109 [00:00<00:00, 224.55it/s]
#   0%|          | 0/109 [00:00<?, ?it/s](get_result pid=2127645) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
# (get_result pid=2128947) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2128947) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2128947) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2128947)
# (get_result pid=2128947) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2127645) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:
# (get_result pid=2127645) A value is trying to be set on a copy of a slice from a DataFrame.
# (get_result pid=2127645) Try using .loc[row_indexer,col_indexer] = value instead
# (get_result pid=2127645)
# (get_result pid=2127645) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy
# (get_result pid=2128947) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction.
#   1%|          | 1/109 [00:02<05:20,  2.97s/it](get_result pid=2153865) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
#  38%|███▊      | 41/109 [00:06<00:04, 16.52it/s](get_result pid=2153951) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 42x across cluster]
# (get_result pid=2153951) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 42x across cluster]
# (get_result pid=2153951) Try using .loc[row_indexer,col_indexer] = value instead [repeated 42x across cluster]
# (get_result pid=2153951)  [repeated 42x across cluster]
# (get_result pid=2153951) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 42x across cluster]
# (get_result pid=2153865) /tmp/ipykernel_1919902/663590851.py:127: FutureWarning: Dropping of nuisance columns in DataFrame reductions (with 'numeric_only=None') is deprecated; in a future version this will raise TypeError.  Select only valid columns before calling the reduction. [repeated 42x across cluster]
# (get_result pid=2153554) No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.) [repeated 37x across cluster]
# 100%|██████████| 109/109 [00:12<00:00,  9.03it/s]
# (get_result pid=2153554) /tmp/ipykernel_1919902/663590851.py:55: SettingWithCopyWarning:  [repeated 65x across cluster]
# (get_result pid=2153554) A value is trying to be set on a copy of a slice from a DataFrame. [repeated 65x across cluster]
# (get_result pid=2153554) Try using .loc[row_indexer,col_indexer] = value instead [repeated 65x across cluster]
# (get_result pid=2153554)  [repeated 65x across cluster]
# (get_result pid=2153554) See the caveats in the documentation: https://pandas.pydata.org/pandas-docs/stable/user_guide/indexing.html#returning-a-view-versus-a-copy [repeated 65x across cluster]
#
#
#
# 100%|██████████| 11/11 [08:22<00:00, 45.64s/it]
# symbol: CLX
# dff.mean():
#  vwap_advantage               -1.339922
# oracle_advantage             -1.846445
# order_flow_1min_advantage    -0.986790
# order_flow_15min_advantage   -0.509134
# twap_advantage                0.040412
# dtype: float64

# %%
# Out:
# dict_items([('AAL',            date  vwap_advantage  oracle_advantage  order_flow_1min_advantage  \
date  vwap_advantage  oracle_advantage  order_flow_1min_advantage  \
#   0    2017-07-20       -0.249492          0.799985                  -3.138775
#   1    2017-07-21       -7.939299         -4.087598                   7.744729
#   2    2017-07-24       -0.355520         -2.309658                  -3.514519
#   3    2017-07-25       -2.095605         -6.509914                  -0.728828
#   4    2017-07-26       -2.011168         -0.855677                   1.645812
#   ..          ...             ...               ...                        ...
#   104  2017-12-20       -1.409130         -0.903440                   5.919465
#   105  2017-12-21        0.580267         -0.243103                  -0.600636
#   106  2017-12-22       -0.406412         -0.334502                   0.933483
#   107  2017-12-26        0.448456          1.742384                  -2.182900
#   108  2017-12-27        0.885733          1.922868                  -5.678529
#
#        order_flow_15min_advantage  twap_advantage
#   0                     -3.134751        1.789102
#   1                      7.776237       -4.398378
#   2                     -2.036509        0.887172
#   3                     -1.438724       -2.841368
#   4                      1.545321       -0.169248
#   ..                          ...             ...
#   104                    5.151269       -4.138452
#   105                    0.350413        4.263574
#   106                    1.288723        0.011042
#   107                   -1.855621       -0.664226
#   108                   -4.846138        0.998486
#
#   [109 rows x 6 columns]}]

# %%
from collections import ChainMap
results = dict(ChainMap(*results))

# %%
results['CLX']
# Out:
#            date  vwap_advantage  oracle_advantage  order_flow_1min_advantage  \
# 0    2017-07-20       -0.249492          0.799985                  -3.138775
# 1    2017-07-21       -7.939299         -4.087598                   7.744729
# 2    2017-07-24       -0.355520         -2.309658                  -3.514519
# 3    2017-07-25       -2.095605         -6.509914                  -0.728828
# 4    2017-07-26       -2.011168         -0.855677                   1.645812
# ..          ...             ...               ...                        ...
# 104  2017-12-20       -1.409130         -0.903440                   5.919465
# 105  2017-12-21        0.580267         -0.243103                  -0.600636
# 106  2017-12-22       -0.406412         -0.334502                   0.933483
# 107  2017-12-26        0.448456          1.742384                  -2.182900
# 108  2017-12-27        0.885733          1.922868                  -5.678529
#
#      order_flow_15min_advantage  twap_advantage
# 0                     -3.134751        1.789102
# 1                      7.776237       -4.398378
# 2                     -2.036509        0.887172
# 3                     -1.438724       -2.841368
# 4                      1.545321       -0.169248
# ..                          ...             ...
# 104                    5.151269       -4.138452
# 105                    0.350413        4.263574
# 106                    1.288723        0.011042
# 107                   -1.855621       -0.664226
# 108                   -4.846138        0.998486
#
# [109 rows x 6 columns]

# %%
lst = []
for syb, dff in results.items(): 
    dff1 = dff.mean()
    dff1.name = syb
    # dff2 = dff1.reset_index()
    lst.append(dff1)

# %%
dff2 =pd.concat(lst,axis=1)
dff2
# Out:
#                                  CLX       BAC       ACN      ABMD      ABBV  \
# vwap_advantage             -1.339922  0.753995 -0.939506 -1.034934 -1.866399
# oracle_advantage           -1.846445  0.721838 -1.274510 -1.410020 -1.817647
# order_flow_1min_advantage  -0.986790 -2.107184 -0.150266 -7.018110 -2.665352
# order_flow_15min_advantage -0.509134 -0.007142  0.163692  0.181022 -0.724264
# twap_advantage              0.040412  0.553338 -0.118278 -0.372054 -0.721602
# date                             NaN       NaN       NaN       NaN       NaN
#
#                                  AAP  CHD ADBE       ABT       ABC       AAL
# vwap_advantage             -0.742033  NaN  NaN -1.006774 -3.374709 -1.903330
# oracle_advantage            0.346790  NaN  NaN -0.758981 -5.351921  0.586819
# order_flow_1min_advantage   1.006242  NaN  NaN -1.531447 -3.910911 -6.566805
# order_flow_15min_advantage  1.095633  NaN  NaN -0.562389 -3.715139 -0.052237
# twap_advantage             -0.634349  NaN  NaN -0.586578 -0.186915  0.814786
# date                             NaN  NaN  NaN       NaN       NaN       NaN
#   0%|          | 0/11 [20:11<?, ?it/s]
#  12%|█▏        | 13/109 [20:11<2:29:03, 93.16s/it]

# %%
dff2.mean(axis=1)
# Out:
# vwap_advantage               -1.272623
# oracle_advantage             -1.200453
# order_flow_1min_advantage    -2.658958
# order_flow_15min_advantage   -0.458884
# twap_advantage               -0.134582
# date                               NaN
# dtype: float64

# %% [markdown]
# symbol: CLX
# dff.mean():
#  vwap_advantage               -1.339922
# oracle_advantage             -1.846445
# order_flow_1min_advantage    -0.986790
# order_flow_15min_advantage   -0.509134
# twap_advantage                0.040412
# dtype: float64

# %%
dff
# Out:
#            date  vwap_advantage  oracle_advantage  order_flow_1min_advantage  \
# 0    2017-07-20        0.256397          2.899657                  -5.271857
# 1    2017-07-21       -6.112885         -5.451359                -127.525759
# 2    2017-07-24      -11.978460        -16.605627                  10.460386
# 3    2017-07-25        3.665251          3.102270                   0.652510
# 4    2017-07-26        1.183655          1.921688                   2.020645
# ..          ...             ...               ...                        ...
# 104  2017-12-20       -7.408576         -5.067466                 -88.367653
# 105  2017-12-21        5.126904         22.671234                 -18.805535
# 106  2017-12-22        0.907588          0.911173                   0.281631
# 107  2017-12-26        2.680681         -1.873994                -388.680978
# 108  2017-12-27       -1.243394         -2.476004                -107.737400
#
#      order_flow_15min_advantage  twap_advantage
# 0                     -2.599868       -2.223056
# 1                     -2.560801        1.633006
# 2                     13.093549        5.842998
# 3                      0.935232        7.522652
# 4                      1.308360        3.613736
# ..                          ...             ...
# 104                   -1.889657       -0.917522
# 105                    6.079981       27.900281
# 106                    0.249283        0.033097
# 107                  -11.747527        3.864256
# 108                   -0.620252        1.481694
#
# [109 rows x 6 columns]

# %% [markdown]
# ('GPN',
#  vwap_advantage               -0.729623
#  oracle_advantage             -1.740881
#  order_flow_1min_advantage    -0.538163
#  order_flow_15min_advantage   -0.080671
#  twap_advantage               -0.343842
#  dtype: float64)
# ('GS',
#  vwap_advantage               -0.133998
#  oracle_advantage             -0.891712
#  order_flow_1min_advantage     0.098627
#  order_flow_15min_advantage    0.275603
#  twap_advantage                0.479491
#  dtype: float64)
# ('FITB',
#  vwap_advantage               -0.204038
#  oracle_advantage              0.302057
#  order_flow_1min_advantage    -1.598390
#  order_flow_15min_advantage   -0.939775
#  twap_advantage                1.224068
#  dtype: float64)
# ('AEP',
#  vwap_advantage               -1.353721
#  oracle_advantage             -1.219461
#  order_flow_1min_advantage     0.156012
#  order_flow_15min_advantage    0.126018
#  twap_advantage               -1.018477
#  dtype: float64)
# ('AAPL',
#  vwap_advantage               -13.522610
#  oracle_advantage             -24.195390
#  order_flow_1min_advantage    -71.054670
#  order_flow_15min_advantage    -6.265439
#  twap_advantage                 4.191287
#  dtype: float64)
# ('GPC',
#  vwap_advantage               -0.354707
#  oracle_advantage             -1.757730
#  order_flow_1min_advantage     1.654710
#  order_flow_15min_advantage    2.159734
#  twap_advantage               -0.465167
#  dtype: float64)

# %% [markdown]
# I guess the RMs  VWAPs and ORACLEs are not the right data returns and might mix up

# %%
dff[['order_flow_15min_advantage','oracle_advantage']].plot()
# Out:
# <AxesSubplot:>

# %% [markdown]
# ### debug cell

# %%
date = dates[0]
ob, msg, date = obs[date],msgs[date],date

# %%
# prepare ob msg  
msg.columns = ['time', 'type', 'id', 'qty', 'price', 'direct', 'remark']  
# df  
df = pd.concat([msg, ob], axis=1)  
df.time *= 1e9  
df.time = df.time.apply(pd.to_datetime)  
df.time = df.time.dt.time  
df['shorten_time'] = pd.to_datetime(df['time'].apply(lambda x:str(x).split('.')[0]), format='%H:%M:%S').dt.strftime('%H%M').astype(str)  
# df['shorten_time'] = pd.to_datetime(df['time'], format='%H:%M:%S.%f').dt.strftime('%H%M').astype(str)  
df = df[(df['shorten_time'] >= '0930') & (df['shorten_time'] < '1600')]  
# truncate
mean = df[[f'bid_price_{i}' for i in range(10)]].mean().mean() 
# mean = df[[f'bid_price_{i}' for i in range(5)]].mean().mean() 
mean_ceilling = mean * 10
mean_bottom = mean * 0.1
for i in range(10):
    df=df[(mean_bottom<=df[f'bid_price_{i}']) & (df[f'bid_price_{i}']<=mean_ceilling)]

g=df.groupby('shorten_time')
lst = []
for idx, itm in g: 
    itm['order_flow_volume_1min'] = itm[itm['type']==4]['qty'].sum()
    lst.append(itm)
df=pd.concat(lst)

# task  
df['trading_volume'] = df[df.type == 4].qty.sum()  
task_ratio = 0.05  
df['task_volume'] = (df.trading_volume * task_ratio).apply(int)  
# dfa  
dfa = df.drop_duplicates('shorten_time', keep='last')  

# bin_time
# Function to round time to the nearest 15-minute bin
def round_time_to_nearest_15min(dt):
    # Round down to the nearest hour
    rounded_hour = dt.floor('H')
    # Find the minutes part of the datetime
    minutes = dt.minute
    # Determine the bin by dividing the minutes by 15, taking the floor, and multiplying back by 15
    bin_minutes = (minutes // 15) * 15
    # Return the rounded hour plus the binned minutes, setting seconds and microseconds to 0
    return rounded_hour + pd.Timedelta(minutes=bin_minutes)
# Apply the rounding function to the 'time' column to create the 'bin_time' column
dfa['bin_time'] =  pd.to_datetime(dfa['time'], format='%H:%M:%S.%f').apply(round_time_to_nearest_15min).dt.strftime('%H%M')
dfa.reset_index(inplace=True,drop=True)

# order_flow_volume_15min
g=dfa.groupby('bin_time')
lst = []
for idx, itm in g: 
    itm['order_flow_volume_15min'] = itm['order_flow_volume_1min'].sum()
    lst.append(itm)
dfa=pd.concat(lst)


# rm  
def get_aligned_values(VWAPs):  
    vwap = VWAPs[symbol].loc[date, :]  
    vwap = vwap.reset_index()  
    vwap.timeHMs = vwap.timeHMs.astype(int).astype(str).apply(lambda x: x.zfill(4))  
    vwap.drop('level_0', axis=1, inplace=True)  
    time_df = pd.DataFrame(df.shorten_time.unique(), columns=['timeHMs'])  
    dfb = pd.merge(vwap, time_df, how='right', on='timeHMs')  
    dfb.fillna(method='ffill', inplace=True)  
    return dfb.iloc[:, -1].to_numpy()  

# jax  
import jax  
import jax.numpy as jnp  

@jax.jit  
def hamilton_apportionment_permuted_jax(votes, seats, key):  
    init_seats, remainders = jnp.divmod(votes, jnp.sum(votes) / seats)  # std_divisor = jnp.sum(votes) / seats  
    remaining_seats = jnp.array(seats - init_seats.sum(), dtype=jnp.int32)  # in {0,1,2,3}  

    def f(carry, x):  
        key, init_seats, remainders = carry  
        key, subkey = jax.random.split(key)  
        chosen_index = jax.random.choice(subkey, remainders.size, p=(remainders == remainders.max()) / (remainders == remainders.max()).sum())  
        return (key, init_seats.at[chosen_index].add(jnp.where(x < remaining_seats, 1, 0)), remainders.at[chosen_index].set(0)), x  

    (key, init_seats, remainders), x = jax.lax.scan(f, (key, init_seats, remainders), xs=jnp.arange(votes.shape[0]))  
    return init_seats.astype(jnp.int32)  

rng = jax.random.PRNGKey(0)  
rng, key = jax.random.split(rng, 2)  

# dfa with task info  
dfa['vwap'] = hamilton_apportionment_permuted_jax(get_aligned_values(VWAPs), dfa.task_volume.iloc[0], key)  
dfa['oracle'] = hamilton_apportionment_permuted_jax(get_aligned_values(ORACLEs), dfa.task_volume.iloc[0], key)  
dfa['order_flow_1min'] = hamilton_apportionment_permuted_jax(dfa['order_flow_volume_1min'].to_numpy(), dfa.task_volume.iloc[0], key)  
dfa['order_flow_15min'] = hamilton_apportionment_permuted_jax(dfa['order_flow_volume_15min'].to_numpy(), dfa.task_volume.iloc[0], key)  
dfa['rm'] = hamilton_apportionment_permuted_jax(get_aligned_values(RMs), dfa.task_volume.iloc[0], key)  
dfa['twap'] = hamilton_apportionment_permuted_jax(get_aligned_values(TWAPs), dfa.task_volume.iloc[0], key)  

# revenue
def f(x, string):
    qty = x[string]
    levels = [(f'bid_price_{i}', f'bid_qty_{i}') for i in range(10)]
    revenue, accumulated_qty = 0, 0
    
    for level_price, level_qty in levels:
        if qty <= accumulated_qty + x[level_qty]:
            revenue = revenue + (qty - accumulated_qty) * x[level_price]
            break
        revenue += x[level_qty] * x[level_price]
        accumulated_qty += x[level_qty]
    return revenue


for s in ['vwap','oracle','order_flow_1min','order_flow_15min','rm','twap']:
# for s in ['vwap','oracle','rm','twap']:
    dfa[s+'_revenue'] = dfa.apply(lambda x: f(x,s),axis=1)

# results  
dfs = dfa.sum()  
vwap_advantage = (dfs.vwap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
oracle_advantage = (dfs.oracle_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
order_flow_1min_advantage = (dfs.order_flow_1min_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
order_flow_15min_advantage = (dfs.order_flow_15min_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
twap_advantage = (dfs.twap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
# result = [date, vwap_advantage, oracle_advantage, twap_advantage]   
result = [date, vwap_advantage, oracle_advantage, order_flow_1min_advantage, order_flow_15min_advantage, twap_advantage]

# %%
dfc = dfa[['oracle','order_flow_1min','order_flow_15min','rm']]
# dfc = dfa[['vwap','oracle','order_flow','rm']]
# dfc = dfa[['vwap','oracle','order_flow','rm','twap']]
dfc.reset_index(drop=True, inplace=True)
dfc.plot(figsize=(12,8))
# Out:
# <AxesSubplot:>

# %%
du -h ~/cmem  | sort -rh | head -n 20

# %%
def get_result(ob, msg, date):
    try:
        # prepare ob msg  
        msg.columns = ['time', 'type', 'id', 'qty', 'price', 'direct', 'remark']  
        # df  
        df = pd.concat([msg, ob], axis=1)  
        df.time *= 1e9  
        df.time = df.time.apply(pd.to_datetime)  
        df.time = df.time.dt.time  
        df['shorten_time'] = pd.to_datetime(df['time'].apply(lambda x:str(x).split('.')[0]), format='%H:%M:%S').dt.strftime('%H%M').astype(str)  
        # df['shorten_time'] = pd.to_datetime(df['time'], format='%H:%M:%S.%f').dt.strftime('%H%M').astype(str)  
        df = df[(df['shorten_time'] >= '0930') & (df['shorten_time'] < '1600')]  
        # truncate
        mean = df[[f'bid_price_{i}' for i in range(10)]].mean().mean() 
        # mean = df[[f'bid_price_{i}' for i in range(5)]].mean().mean() 
        mean_ceilling = mean * 10
        mean_bottom = mean * 0.1
        for i in range(10):
            df=df[(mean_bottom<=df[f'bid_price_{i}']) & (df[f'bid_price_{i}']<=mean_ceilling)]
        # task  
        df['trading_volume'] = df[df.type == 4].qty.sum()  
        task_ratio = 0.05  
        df['task_volume'] = (df.trading_volume * task_ratio).apply(int)  
        # dfa  
        dfa = df.drop_duplicates('shorten_time', keep='last')  
            
        # date  
        # date = dates[i]  
        # date = '2017-07-20'  # {from file can get this} - This comment suggests you might want to extract the date from a file.  

        # rm  
        def get_aligned_values(VWAPs):  
            vwap = VWAPs[symbol].loc[date, :]  
            vwap = vwap.reset_index()  
            vwap.timeHMs = vwap.timeHMs.astype(int).astype(str).apply(lambda x: x.zfill(4))  
            vwap.drop('level_0', axis=1, inplace=True)  
            time_df = pd.DataFrame(df.shorten_time.unique(), columns=['timeHMs'])  
            dfb = pd.merge(vwap, time_df, how='right', on='timeHMs')  
            dfb.fillna(method='ffill', inplace=True)  
            return dfb.iloc[:, -1].to_numpy()  

        # jax  
        import jax  
        import jax.numpy as jnp  

        @jax.jit  
        def hamilton_apportionment_permuted_jax(votes, seats, key):  
            init_seats, remainders = jnp.divmod(votes, jnp.sum(votes) / seats)  # std_divisor = jnp.sum(votes) / seats  
            remaining_seats = jnp.array(seats - init_seats.sum(), dtype=jnp.int32)  # in {0,1,2,3}  

            def f(carry, x):  
                key, init_seats, remainders = carry  
                key, subkey = jax.random.split(key)  
                chosen_index = jax.random.choice(subkey, remainders.size, p=(remainders == remainders.max()) / (remainders == remainders.max()).sum())  
                return (key, init_seats.at[chosen_index].add(jnp.where(x < remaining_seats, 1, 0)), remainders.at[chosen_index].set(0)), x  

            (key, init_seats, remainders), x = jax.lax.scan(f, (key, init_seats, remainders), xs=jnp.arange(votes.shape[0]))  
            return init_seats.astype(jnp.int32)  

        rng = jax.random.PRNGKey(0)  
        rng, key = jax.random.split(rng, 2)  

        # dfa with task info  
        dfa['vwap'] = hamilton_apportionment_permuted_jax(get_aligned_values(VWAPs), dfa.task_volume.iloc[0], key)  
        dfa['oracle'] = hamilton_apportionment_permuted_jax(get_aligned_values(ORACLEs), dfa.task_volume.iloc[0], key)  
        dfa['rm'] = hamilton_apportionment_permuted_jax(get_aligned_values(RMs), dfa.task_volume.iloc[0], key)  
        dfa['twap'] = hamilton_apportionment_permuted_jax(get_aligned_values(TWAPs), dfa.task_volume.iloc[0], key)  
        
        # revenue
        def f(x, string):
            qty = x[string]
            levels = [(f'bid_price_{i}', f'bid_qty_{i}') for i in range(10)]
            revenue, accumulated_qty = 0, 0
            
            for level_price, level_qty in levels:
                if qty <= accumulated_qty + x[level_qty]:
                    revenue = revenue + (qty - accumulated_qty) * x[level_price]
                    break
                revenue += x[level_qty] * x[level_price]
                accumulated_qty += x[level_qty]
            return revenue

        
        
        for s in ['vwap','oracle','rm','twap']:
            dfa[s+'_revenue'] = dfa.apply(lambda x: f(x,s),axis=1)

        # results  
        dfs = dfa.sum()  
        vwap_advantage = (dfs.vwap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        oracle_advantage = (dfs.oracle_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        twap_advantage = (dfs.twap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        result = [date, vwap_advantage, oracle_advantage, twap_advantage]  
        return result
    except Exception as e:
        print(f"Error reading {symbol} on {date}: {e}")
date = dates[0]
get_result(obs[date],msgs[date],date)
# Out:
# ['2017-07-20', -7.291903279886818, -13.44010572739088, -5.185654710372451]

# %% [markdown]
# ### debug cell

# %%
# %%bash
# cd /homes/80/kang/cmem/data/
# tar -czvf 01_raw_rolling_mean_15min_bin.tar.gz /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/
# Out:
# tar: Removing leading `/' from member names
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/A.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AAL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AAP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AAPL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ABBV.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ABC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ABMD.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ABT.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ACN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADBE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADM.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ADSK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AEE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AEP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AES.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AFL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AIG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AIV.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AIZ.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AJG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AKAM.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALB.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALGN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALLE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ALXN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMAT.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMD.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AME.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMGN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMT.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AMZN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ANET.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ANSS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ANTM.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AON.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AOS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/APA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/APD.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/APH.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ARE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ARNC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ATO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ATVI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AVB.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AVGO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AVY.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AWK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AXP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/AZO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BAC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BAX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BBY.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BDX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BEN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BF.B.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BIIB.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BLK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BLL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BMY.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BRK.B.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BSX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BWA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/BXP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/C.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CAG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CAH.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CAT.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CB.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CBOE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CCI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CCL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CDNS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CDW.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CERN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CF.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CFG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CHD.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CHRW.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CHTR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CINF.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CLX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CMA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CMCSA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CME.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CMG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CMI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CMS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CNC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CNP.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/COF.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/COG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/COO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/COST.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/COTY.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CPB.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CPRT.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CRM.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CSCO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CSX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CTAS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CTL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CTSH.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CTXS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CVS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CVX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/CXO.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/D.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DAL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DFS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DGX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DHI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DHR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DIS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DISCA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DISCK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DISH.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DLR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DLTR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DOV.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DRE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DRI.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DTE.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DUK.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DVA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/DVN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EA.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EBAY.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ECL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ED.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EEM.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EFX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EIX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EL.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EMN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EMR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EOG.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EQIX.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EQR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ES.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ESS.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ETFC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ETN.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/ETR.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EW.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/EXC.csv
# /homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/
es/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/"
onlyFiles = sorted([f for f in listdir(dir0) if isfile(join(dir0, f))])
from tqdm import tqdm
for i in tqdm(range(len(onlyFiles))):
    
    name = onlyFiles[i]
    df = pd.read_pickle(dir0+name)
    d = df[['symbol','date','timeHMs','timeHMe','qty']]
    g = d.groupby('timeHMs')
    lst = []
    for idx, itm in g:
        pass
        value = itm.shift(1).rolling(5).mean()
        # itm.shift(-1).rolling(5).mean()
        value.date = itm.date
        lst.append(value)
    # itm.qty[:5].mean()
    f = pd.concat(lst,axis=0)
    f['symbol'] = name[:-4]
    ff = f.sort_index().dropna()
    ff.to_csv(dir1+name[:-4]+".csv")
# Out:
#   0%|          | 0/497 [00:00<?, ?it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   0%|          | 1/497 [00:00<02:19,  3.57it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   0%|          | 2/497 [00:00<01:40,  4.94it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   1%|          | 3/497 [00:00<01:28,  5.57it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   1%|          | 4/497 [00:00<01:21,  6.02it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   1%|          | 5/497 [00:00<01:18,  6.28it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   1%|          | 6/497 [00:01<01:16,  6.43it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   1%|▏         | 7/497 [00:01<01:17,  6.33it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   2%|▏         | 8/497 [00:01<01:17,  6.33it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   2%|▏         | 9/497 [00:01<01:20,  6.04it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   2%|▏         | 10/497 [00:01<01:15,  6.45it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   2%|▏         | 11/497 [00:01<01:10,  6.86it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   2%|▏         | 12/497 [00:01<01:08,  7.09it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   3%|▎         | 13/497 [00:02<01:08,  7.09it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   3%|▎         | 14/497 [00:02<01:07,  7.12it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   3%|▎         | 15/497 [00:02<01:07,  7.13it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   3%|▎         | 16/497 [00:02<01:09,  6.87it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   3%|▎         | 17/497 [00:02<01:08,  7.00it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   4%|▎         | 18/497 [00:02<01:04,  7.39it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   4%|▍         | 19/497 [00:02<01:04,  7.43it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   4%|▍         | 20/497 [00:02<01:01,  7.70it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   4%|▍         | 21/497 [00:03<01:03,  7.48it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   4%|▍         | 22/497 [00:03<01:06,  7.10it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   5%|▍         | 23/497 [00:03<01:08,  6.95it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   5%|▍         | 24/497 [00:03<01:13,  6.41it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   5%|▌         | 25/497 [00:03<01:13,  6.45it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   5%|▌         | 26/497 [00:03<01:10,  6.71it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   5%|▌         | 27/497 [00:04<01:10,  6.70it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   6%|▌         | 28/497 [00:04<01:10,  6.68it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   6%|▌         | 29/497 [00:04<01:09,  6.70it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   6%|▌         | 30/497 [00:04<01:09,  6.70it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   6%|▌         | 31/497 [00:04<01:08,  6.78it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   6%|▋         | 32/497 [00:04<01:08,  6.77it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   7%|▋         | 33/497 [00:04<01:10,  6.58it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   7%|▋         | 34/497 [00:05<01:09,  6.61it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   7%|▋         | 35/497 [00:05<01:11,  6.50it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   7%|▋         | 36/497 [00:05<01:10,  6.57it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   7%|▋         | 37/497 [00:05<01:08,  6.69it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   8%|▊         | 38/497 [00:05<01:11,  6.41it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   8%|▊         | 39/497 [00:05<01:09,  6.57it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   8%|▊         | 40/497 [00:06<01:12,  6.30it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   8%|▊         | 41/497 [00:06<01:10,  6.48it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   8%|▊         | 42/497 [00:06<01:07,  6.76it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   9%|▊         | 43/497 [00:06<01:06,  6.78it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   9%|▉         | 44/497 [00:06<01:03,  7.10it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   9%|▉         | 45/497 [00:06<01:03,  7.10it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   9%|▉         | 46/497 [00:06<01:04,  7.04it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#   9%|▉         | 47/497 [00:07<01:05,  6.90it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  10%|▉         | 48/497 [00:07<01:02,  7.15it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#
/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  96%|█████████▌| 478/497 [01:07<00:02,  6.93it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  96%|█████████▋| 479/497 [01:07<00:02,  6.96it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  97%|█████████▋| 480/497 [01:07<00:02,  6.88it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  97%|█████████▋| 481/497 [01:07<00:02,  7.16it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  97%|█████████▋| 482/497 [01:08<00:02,  7.34it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  97%|█████████▋| 483/497 [01:08<00:01,  7.56it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  97%|█████████▋| 484/497 [01:08<00:01,  7.59it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  98%|█████████▊| 485/497 [01:08<00:01,  7.78it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  98%|█████████▊| 486/497 [01:08<00:01,  7.79it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  98%|█████████▊| 487/497 [01:08<00:01,  7.02it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  98%|█████████▊| 488/497 [01:09<00:02,  3.27it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  98%|█████████▊| 489/497 [01:09<00:02,  3.92it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  99%|█████████▊| 490/497 [01:09<00:01,  4.28it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  99%|█████████▉| 491/497 [01:09<00:01,  4.86it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  99%|█████████▉| 492/497 [01:10<00:00,  5.14it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  99%|█████████▉| 493/497 [01:10<00:00,  5.89it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
#  99%|█████████▉| 494/497 [01:10<00:00,  6.65it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
# 100%|█████████▉| 495/497 [01:10<00:00,  6.82it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
# 100%|█████████▉| 496/497 [01:10<00:00,  6.81it/s]/tmp/ipykernel_3543919/2431534768.py:17: FutureWarning: Dropping of nuisance columns in rolling operations is deprecated; in a future version this will raise TypeError. Select only valid columns before calling the operation. Dropped columns were Index(['symbol'], dtype='object')
#   value = itm.shift(1).rolling(5).mean()
# 100%|██████████| 497/497 [01:10<00:00,  7.03it/s]

# %%
from os import listdir  
from tqdm import tqdm  
import pandas as pd  
import numpy as np
import warnings
pd.options.mode.chained_assignment = None  # default='warn'
warnings.simplefilter(action='ignore', category=FutureWarning)

def data_alignment(ATFolder):
    '''
    The logic here is to load the three dir: messages data, rolling mean and vwap
    Then find the common_dates of all these three,
    Then pass into the init of the base env, 
    To only load the data window in the common dates.
    But we should also align the symbols, it has been done, as we will pass symbols 
    into the load_forecasted_and_original_volume_VWAP and load_forecasted_volume_RM
    '''
    def load_forecasted_and_original_volume_VWAP(symbol):
        import pandas as pd
        import numpy as np
        dir = '/homes/80/kang/cmem/output/0900_r_output_with_features_csv_fractional_shares_clipped_vwap/'
        df = pd.read_csv(dir+f'{symbol}.csv',index_col=0)
        df['symbol'] = symbol
        from datetime import datetime, timedelta
        timeHMs = np.array([int((datetime(2023, 1, 1, 9, 30) + i * timedelta(minutes=15)).strftime('%H%M')) for i in range(26)])
        timeHMs = np.tile(timeHMs, (1, int(df.shape[0]/timeHMs.shape[0]))).squeeze()
        df['timeHMs'] = timeHMs
        df = df[['date', 'timeHMs', 'x', 'qty', 'symbol']]
        d = df[['date', 'timeHMs', 'x']].pivot(index = 'date', columns = 'timeHMs')
        f = df[['date', 'timeHMs', 'qty']].pivot(index = 'date', columns = 'timeHMs')
        return d, f # x, qty

    def load_forecasted_volume_RM(symbol):
        import pandas as pd
        import numpy as np
        dir = '/homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/'
        pd.read_csv('/homes/80/kang/cmem/data/01_raw_rolling_mean_15min_bin/GPN.csv')
        df = pd.read_csv(dir+f'{symbol}.csv',index_col=0)
        df.columns = ['date', 'timeHMs', 'timeHMe', 'x_rm', 'symbol']
        df.date = df.date.apply(lambda d: str(d)[:4]+'-'+str(d)[4:6]+'-'+str(d)[6:8]) if len(str(df.date[0])) == 8 else df.date
        d = df[['date', 'timeHMs', 'x_rm']].pivot(index = 'date', columns = 'timeHMs')
        d = d.fillna(method = "ffill")
        return d # x

    def load_files(symbol):
        alphatradePath = ATFolder
        # alphatradePath = f"{ATFolder}/{symbol}_data"
        messagePath = alphatradePath+"/Flow_10/"
        orderbookPath = alphatradePath+"/Book_10/"
        from os import listdir; from os.path import isfile, join; import pandas as pd
        readFromPath = lambda data_path: sorted([f for f in listdir(data_path) if isfile(join(data_path, f))])
        messageFiles, orderbookFiles = readFromPath(messagePath), readFromPath(orderbookPath)
        message_dates = np.array([m[4:14] for m in messageFiles])
        message_dates = np.array([m.split("_")[1] for m in messageFiles])
        return message_dates
    
    def get_symbols():
        from os.path import isdir
        from os import listdir
        path_dir1 = '/homes/80/kang/cmem/output/0900_r_output_with_features_csv_fractional_shares_clipped_vwap/'
        path_dir2 = ATFolder
        symbols1 = np.array([dirname.split(".")[0] for dirname in listdir(path_dir1)])
        symbols2 = np.array([path_dir2.split("_")[0].split("/")[-1]])
        # symbols2 = np.array([dirname.split("_")[0] for dirname in listdir(path_dir2) 
        #             if isdir(os.path.join(path_dir2, dirname))])
        intersection = np.intersect1d(symbols1, symbols2)
        return intersection
    common_stocks = get_symbols()
    assert len(common_stocks) >= 1
    
    def get_raw_VWAPs_ORACLEs_RMs():
        ds = [(symbol, *load_forecasted_and_original_volume_VWAP(symbol)) for symbol in common_stocks]
        VWAPs = [(d[0], d[1]) for d in ds]
        ORACLEs = [(d[0], d[2]) for d in ds]
        RMs = [(symbol, load_forecasted_volume_RM(symbol)) for symbol in common_stocks]
        return VWAPs, ORACLEs, RMs
    VWAPs, ORACLEs, RMs = get_raw_VWAPs_ORACLEs_RMs()
    
    def get_common_dates():
        dates_vwap =  VWAPs[-1][-1].index.to_numpy()
        dates_rm =  RMs[-1][-1].index.to_numpy()
        message_dates = load_files(common_stocks[-1]) 
        common_dates = np.intersect1d(np.intersect1d(dates_vwap, message_dates),dates_rm)
        return common_dates
    common_dates = get_common_dates()
    
    def align_dates(Xs):
        Xs = {d[0]: d[1].loc[common_dates] for d in Xs}
        return Xs
    VWAPs, ORACLEs, RMs = list(map(align_dates, [VWAPs, ORACLEs, RMs]))

    def generate_TWAPs(RMs):
        def f(df):
            dff = df.copy()
            dff.loc[:, :] = 1
            return dff
        return {symbol: f(df) for symbol, df in RMs.items()}
    TWAPs = generate_TWAPs(RMs)
            
    return common_dates, common_stocks, VWAPs, ORACLEs, RMs, TWAPs


  
lst = ['AEP','GS','FITB','GPN','AAPL']
symbol = 'GPC' 
  
ATFolder = f"/homes/80/kang/SP500/{symbol}_data"  
# ATFolder = f"/scratch/local/kang/SP500/{symbol}_data"  
common_dates, common_stocks, VWAPs, ORACLEs, RMs, TWAPs = data_alignment(ATFolder)  
obs = [pd.read_csv(ATFolder + "/Book_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Book_10/"))]  
msgs = [pd.read_csv(ATFolder + "/Flow_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Flow_10/"))]  
# obs = [pd.read_csv(ATFolder + "/Book_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Book_10/")[:2])]  
# msgs = [pd.read_csv(ATFolder + "/Flow_10/" + file, header=None) for file in tqdm(listdir(ATFolder + "/Flow_10/")[:2])]  
lobster_dates = [file.split("_")[1] for file in listdir(ATFolder + "/Book_10/")]
dates = np.intersect1d(common_dates, lobster_dates)
assert len(obs) == len(msgs)  
  

results = []  
# for i in tqdm([18]):  
# for i in tqdm(range(15,len(obs))):  
for i in tqdm(range(len(obs))):  
    try:
        # prepare ob msg  
        ob = obs[i]  
        obs1 = ob.iloc[:, [0, 1, 4, 5, 8, 9]]  
        obs1.columns = ['best_ask', 'best_qty', 'second_ask', 'second_qty', 'third_ask', 'third_qty']  
        msg = msgs[i]  
        msg.columns = ['time', 'type', 'id', 'qty', 'price', 'direct', 'remark']  
    
        # df  
        df = pd.concat([msg, obs1], axis=1)  
        df.time *= 1e9  
        df.time = df.time.apply(pd.to_datetime)  
        df.time = df.time.dt.time  
        df['shorten_time'] = pd.to_datetime(df['time'].apply(lambda x:str(x).split('.')[0]), format='%H:%M:%S').dt.strftime('%H%M').astype(str)  
        # df['shorten_time'] = pd.to_datetime(df['time'], format='%H:%M:%S.%f').dt.strftime('%H%M').astype(str)  
        df = df[(df['shorten_time'] >= '0930') & (df['shorten_time'] < '1600')]  
    
        # task  
        df['trading_volume'] = df[df.type == 4].qty.sum()  
        task_ratio = 0.05  
        df['task_volume'] = (df.trading_volume * task_ratio).apply(int)  
    
        # dfa  
        dfa = df.drop_duplicates('shorten_time', keep='last')  
    
        # date  
        date = dates[i]  
        # date = '2017-07-20'  # {from file can get this} - This comment suggests you might want to extract the date from a file.  
    
        # rm  
        def get_aligned_values(VWAPs):  
            vwap = VWAPs[symbol].loc[date, :]  
            vwap = vwap.reset_index()  
            vwap.timeHMs = vwap.timeHMs.astype(int).astype(str).apply(lambda x: x.zfill(4))  
            vwap.drop('level_0', axis=1, inplace=True)  
            time_df = pd.DataFrame(df.shorten_time.unique(), columns=['timeHMs'])  
            dfb = pd.merge(vwap, time_df, how='right', on='timeHMs')  
            dfb.fillna(method='ffill', inplace=True)  
            return dfb.iloc[:, -1].to_numpy()  
    
        # jax  
        import jax  
        import jax.numpy as jnp  
    
        @jax.jit  
        def hamilton_apportionment_permuted_jax(votes, seats, key):  
            init_seats, remainders = jnp.divmod(votes, jnp.sum(votes) / seats)  # std_divisor = jnp.sum(votes) / seats  
            remaining_seats = jnp.array(seats - init_seats.sum(), dtype=jnp.int32)  # in {0,1,2,3}  
    
            def f(carry, x):  
                key, init_seats, remainders = carry  
                key, subkey = jax.random.split(key)  
                chosen_index = jax.random.choice(subkey, remainders.size, p=(remainders == remainders.max()) / (remainders == remainders.max()).sum())  
                return (key, init_seats.at[chosen_index].add(jnp.where(x < remaining_seats, 1, 0)), remainders.at[chosen_index].set(0)), x  
    
            (key, init_seats, remainders), x = jax.lax.scan(f, (key, init_seats, remainders), xs=jnp.arange(votes.shape[0]))  
            return init_seats.astype(jnp.int32)  
    
        rng = jax.random.PRNGKey(0)  
        rng, key = jax.random.split(rng, 2)  
    
        # dfa with task info  
        dfa['vwap'] = hamilton_apportionment_permuted_jax(get_aligned_values(VWAPs), dfa.task_volume.iloc[0], key)  
        dfa['oracle'] = hamilton_apportionment_permuted_jax(get_aligned_values(ORACLEs), dfa.task_volume.iloc[0], key)  
        dfa['rm'] = hamilton_apportionment_permuted_jax(get_aligned_values(RMs), dfa.task_volume.iloc[0], key)  
        dfa['twap'] = hamilton_apportionment_permuted_jax(get_aligned_values(TWAPs), dfa.task_volume.iloc[0], key)  
    
        # assert  
        assert (dfa.best_qty + dfa.second_qty + dfa.third_qty >= dfa.vwap).all()  
        assert (dfa.best_qty + dfa.second_qty + dfa.third_qty >= dfa.oracle).all()  
        assert (dfa.best_qty + dfa.second_qty + dfa.third_qty >= dfa.rm).all()  
        assert (dfa.best_qty + dfa.second_qty + dfa.third_qty >= dfa.twap).all()  
        
        # revenue
        def f(x,string):
            if x.best_qty>=x[string]:
                price = x.best_ask * x[string]
            elif x.best_qty<x[string]<=x.best_qty+x.second_qty:
                price = x.best_ask*x.best_qty + x.second_ask*(x[string]-x.best_qty)
            elif x.best_qty+x.second_qty<x[string]<=x.best_qty+x.second_qty+x.third_qty:
                price = x.best_ask*x.best_qty + x.second_ask*x.second_qty + x.third_ask*(x[string]-x.best_qty-x.second_qty)
            else:
                raise NotImplementedError
            return price
        for s in ['vwap','oracle','rm','twap']:
            dfa[s+'_revenue'] = dfa.apply(lambda x: f(x,s),axis=1)
    
        # results  
        dfs = dfa.sum()  
        vwap_advantage = (dfs.vwap_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        oracle_advantage = (dfs.oracle_revenue - dfs.rm_revenue) / dfs.rm_revenue * 1e4  
        result = [date, vwap_advantage, oracle_advantage]  
        results.append(result)  
  
    except:
        pass  
dff = pd.DataFrame(results, columns=['date', 'vwap_advantage', 'oracle_advantage'])
# Out:
#   5%|▌         | 13/251 [00:01<00:19, 11.95it/s]
# 100%|██████████| 251/251 [00:19<00:00, 12.88it/s]
# 100%|██████████| 251/251 [00:04<00:00, 59.80it/s]
#   0%|          | 0/251 [00:00<?, ?it/s]No GPU/TPU found, falling back to CPU. (Set TF_CPP_MIN_LOG_LEVEL=0 and rerun for more info.)
# 100%|██████████| 251/251 [09:58<00:00,  2.38s/it]

# %%
dfa
# Out:
#                   time  type         id  qty   price  direct remark  best_ask  \
# 255    09:30:56.920739     3    6491246  100  957000       1    NaN    960000
# 285    09:31:50.097861     3    7125702  100  953500       1    NaN    960000
# 365    09:32:57.290256     1    8371162  100  959400      -1    NaN    959400
# 399    09:33:55.190620     1    9161770  100  955500       1    NaN    958400
# 433    09:34:49.199383     3    9112186  100  955200       1    NaN    958200
# ...                ...   ...        ...  ...     ...     ...    ...       ...
# 17791  15:55:59.221792     3  157772802  200  951600      -1    NaN    951100
# 17993  15:56:54.514651     1  158731114  100  951700      -1    NaN    950900
# 18248  15:57:53.254034     3  159634474  100  950700       1    NaN    951000
# 18518  15:58:59.890950     3  161006618  100  950600       1    NaN    951400
# 19104  15:59:59.501618     3  163490826  200  950900      -1    NaN    950700
#
#        best_qty  second_ask  second_qty  third_ask  third_qty shorten_time  \
# 255         200      961000          10     962600        100         0930
# 285         200      960200           5     960400        100         0931
# 365         400      960000         105     960200          5         0932
# 399         100      958500         100     958700        200         0933
# 433         300      958900           5     959800          5         0934
# ...         ...         ...         ...        ...        ...          ...
# 17791       282      951200         380     951400        100         1555
# 17993       100      951000         100     951400        110         1556
# 18248       100      951200         101     951400        120         1557
# 18518        20      951500         220     951700        300         1558
# 19104       100      950900         100     951100        100         1559
#
#        trading_volume  task_volume
# 255             38703         1935
# 285             38703         1935
# 365             38703         1935
# 399             38703         1935
# 433             38703         1935
# ...               ...          ...
# 17791           38703         1935
# 17993           38703         1935
# 18248           38703         1935
# 18518           38703         1935
# 19104           38703         1935
#
# [379 rows x 16 columns]

# %%
dfs
# Out:
# type                                                            757
# id                                                      46370213302
# qty                                                           36640
# price                                                     367846300
# direct                                                           38
# remark                                                            0
# best_ask                                                  367965600
# best_qty                                                      58567
# second_ask                                                368018000
# second_qty                                                    77132
# third_ask                                                 368074800
# third_qty                                                     91723
# shorten_time      0930093109320933093409350936093709380939094009...
# trading_volume                                             44214690
# task_volume                                                 2210520
# vwap                                                           5668
# oracle                                                         5668
# rm                                                             5668
# twap                                                           5668
# vwap_revenue                                             5346562000
# oracle_revenue                                           5348049200
# rm_revenue                                               5347119400
# twap_revenue                                             5347834400
# dtype: object

# %%
symbol
# Out:
# 'GPC'

# %%
dff
# Out:
#           date  vwap_advantage  oracle_advantage
# 0   2017-07-20        2.734581         10.464847
# 1   2017-07-21       -4.227450         -3.965636
# 2   2017-07-24        0.672123          1.298484
# 3   2017-07-26        1.814326          1.867831
# 4   2017-07-27       -6.614667         -9.789352
# ..         ...             ...               ...
# 84  2017-12-08        0.169195          0.492873
# 85  2017-12-15        4.899289          2.158554
# 86  2017-12-18        1.139581          3.453691
# 87  2017-12-19       -8.869012        -14.453650
# 88  2017-12-20       -1.042430          1.738880
#
# [89 rows x 3 columns]

# %%
dff.mean()
# Out:
# vwap_advantage      1.048364
# oracle_advantage    2.428116
# dtype: float64

# %% [markdown]
# ## find at what percentage level the best bid level was all taken

# %%
(base) kang@flair-node-01:~/AlphaTrade/gymnax_exchange/jaxrl$ python -m pip list | grep jax
jax                           0.4.16
jax-jumpy                     1.0.0
jaxlib                        0.4.12
(base) kang@flair-node-01:~/AlphaTrade/gymnax_exchange/jaxrl$ pip install jax==0.4.12

# %%
total_volume = msg[msg.type==4].qty.sum()

# %%
total_volume*0.01
# Out:
# 37777.57

# %% [markdown]
# # run r to get the cmem results

# %%
cd /homes/80/kang/cmem/data_minmax/02.2_data_r_input_kf_minmax/
# Out:
# /homes/80/kang/cmem/data_minmax/02.2_data_r_input_kf_minmax

# %%
path = '/homes/80/kang/cmem/data_minmax/02.2_data_r_input_kf_minmax/'
from os import listdir
lst = listdir(path)
lstt = [file[:-4] for file in lst]

# %%
for idx, itm in enumerate(lstt):
    if itm in lstsymbols:
        print(idx, itm)
# Out:
# 3 AAPL
# 16 AEP
# 174 FITB
# 196 GPN
# 199 GS

# %% [markdown]
# ## use this r code:
# /homes/80/kang/cmem/rkf_fraction.r
# ## hers is the output dir
# /homes/80/kang/cmem/output/0400_r_kl_output_raw_data_minmax/

# %% [markdown]
# ## check whether all the data is generated correctly

# %%
# %%bash
# cd /homes/80/kang/cmem/output/0400_r_kl_output_raw_data_minmax/
# ls | wc
# Out:
#     472     472    3833

# %%
#  note the data might not all generated

# %% [markdown]
# # we have to generate this after the r code output:
# 0900_r_output_with_features_csv_fractional_shares_clipped_vwap

# %% [markdown]
# ## get symbol  codes

# %%
dir = '/homes/80/kang/cmem/output/0400_r_kl_output_raw_data_minmax/'
import os 
from os import listdir
lst = sorted([file[:-4] for file in listdir(dir)])
len(lst)
# Out:
# 472

# %%
file_path = '/homes/80/kang/cmem/stock_names.txt'
reloaded_stock_names = []
with open(file_path, 'r') as f:
    reloaded_stock_names = [line.strip() for line in f.readlines()]
reloaded_stock_names,len(reloaded_stock_names)
lst = reloaded_stock_names

# %% [markdown]
# ### from mihai's shares outstanding data

# %%
from os import listdir
from os.path import isfile, join
dir0 = "/homes/80/kang/2017daily_csv/"
onlyFiles = sorted([f for f in listdir(dir0) if isfile(join(dir0, f))])
dfflst =[]
i=0
# for i in range(len(onlyFiles)):
print(i)
name = onlyFiles[i]
import pandas as pd
# name ="CMS.csv"

dir = dir0+name
df = pd.read_csv(dir)
mhlst = sorted(df.ticker.to_list())
len(mhlst)
lstt = [file for file in mhlst if file in lst]
len(lstt)
# Out:
# 0
# 384

# %%
lst0=[file for file in lst if file not in lstt]
len(lst0)
# Out:
# 99

# %% [markdown]
# ### lst0 is the missing parts

# %%
lst0
# Out:
# ['A',
#  'AAPL',
#  'ADBE',
#  'ADSK',
#  'AKAM',
#  'ALGN',
#  'ALXN',
#  'AMAT',
#  'AMGN',
#  'AMZN',
#  'ANSS',
#  'ATVI',
#  'AVGO',
#  'BF.B',
#  'BIIB',
#  'BRK.B',
#  'CBOE',
#  'CDW',
#  'CERN',
#  'CHRW',
#  'CHTR',
#  'CINF',
#  'CMCSA',
#  'COST',
#  'CPRT',
#  'CSCO',
#  'CTAS',
#  'CTSH',
#  'CTXS',
#  'DISCA',
#  'DISCK',
#  'DISH',
#  'DLTR',
#  'EA',
#  'EBAY',
#  'EQIX',
#  'EXPD',
#  'EXPE',
#  'FANG',
#  'FAST',
#  'FFIV',
#  'FISV',
#  'FITB',
#  'FLIR',
#  'FTNT',
#  'GILD',
#  'GOOG',
#  'GOOGL',
#  'GRMN',
#  'HBAN',
#  'HOLX',
#  'HSIC',
#  'IDXX',
#  'ILMN',
#  'INTC',
#  'INTU',
#  'IPGP',
#  'ISRG',
#  'JBHT',
#  'JKHY',
#  'KHC',
#  'KLAC',
#  'LKQ',
#  'LRCX',
#  'MCHP',
#  'MKTX',
#  'MNST',
#  'MSFT',
#  'MXIM',
#  'NDAQ',
#  'NFLX',
#  'NTAP',
#  'NTRS',
#  'NVDA',
#  'NWSA',
#  'ODFL',
#  'ORLY',
#  'PAYX',
#  'PBCT',
#  'PCAR',
#  'PYPL',
#  'QCOM',
#  'QRVO',
#  'REGN',
#  'ROST',
#  'SBAC',
#  'SBUX',
#  'SIVB',
#  'SNPS',
#  'SWKS',
#  'TRIP',
#  'TROW',
#  'TSCO',
#  'TTWO',
#  'ULTA',
#  'VRSK',
#  'VRSN',
#  'VRTX',
#  'WYNN']
