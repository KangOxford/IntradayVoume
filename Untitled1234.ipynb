# %%
dir="/homes/80/kang/cmem/output/06_r_output_raw_csv/"
'''should be 0600'''
# Out:
# 'should be 0600'

# %%
import numpy as np
import pandas as pd
from os import listdir;
import time
from os.path import isfile, join;

import os
os.sys.path.append("/home/kanli/cmem/src/")
os.sys.path.append("/Users/kang/CMEM/src/")
os.sys.path.append("/homes/80/kang/cmem/src/")
readFromPath = lambda data_path: sorted([f for f in listdir(data_path) if isfile(join(data_path, f)) and f != '.DS_Store'])

# %%
files=readFromPath(dir)

# %%
names = [file[:-4] for file in files]
len(names)

# %%
# Save the list to a text file
file_path = 'stock_names.txt'
with open(file_path, 'w') as f:
    for name in names:
        f.write(f"{name}\n")
# Out:
# 483

# %%
# Reload the list from the text file
file_path = 'stock_names.txt'
reloaded_stock_names = []
with open(file_path, 'r') as f:
    reloaded_stock_names = [line.strip() for line in f.readlines()]
reloaded_stock_names

# %%
i=0
df=pd.read_csv(dir+files[i],index_col=0)
df
# Out:
#             date  turnover  log_turnover      log_x  log_eta*seas   log_eta  \
# 0     20170707.0    4706.5      8.456700   9.397030      9.402907  9.372005
# 1     20170707.0    8108.5      9.000668   9.167288      9.420839  9.372005
# 2     20170707.0   10713.5      9.279260   9.081451      9.347880  9.372005
# 3     20170707.0    6568.0      8.789965   9.128558      9.277934  9.372005
# 4     20170707.0    9282.5      9.135886   9.153835      9.386567  9.372005
# ...          ...       ...           ...        ...           ...       ...
# 3141  20171228.0    8375.5      9.033066   9.102758      9.266080  9.275864
# 3142  20171228.0    5112.0      8.539346   9.270569      9.431990  9.275864
# 3143  20171228.0    8272.5      9.020692   9.251054      9.588659  9.275864
# 3144  20171228.0   10220.0      9.232102   9.527830      9.880529  9.275864
# 3145  20171228.0   40102.0     10.599181  10.003180     10.386329  9.275864
#
# ...

# %% [markdown]
# # feb 15
# /homes/80/kang/cmem/data_fraction/02.2_data_r_input_kf

# %%
cp /homes/80/kang/cmem/data_fraction/02.2_data_r_input_kf/* /homes/80/kang/cmem/data_fraction/02.2_data_r_input_kf_fraction
